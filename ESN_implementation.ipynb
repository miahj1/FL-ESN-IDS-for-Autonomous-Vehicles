# %% [markdown]
# #Auto-ESN

# %%
# !pip install syft==0.2.9

# %%
# !pip install auto-esn

# %%
import torch
import syft as sy
import pandas as pd
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.nn
import torch.optim as optim
from auto_esn.esn.esn import DeepESN
#from auto_esn.esn.reservoir.util import NRMSELoss

class CarHackingDataset(Dataset):
    """
    Loading the Car-Hacking Dataset from
    https://ocslab.hksecurity.net/Datasets/car-hacking-dataset 

    Args:
        csv_file: A path to the dataset file which has the extension CSV.
        root_dir: The directory of the parent folder of the dataset.
        transform (callable, optional): Optional tansform to be applied on a sample.
    """
    def __init__(self, csv_file: str, root_dir: str, transform=None):
        self.car_hacking_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __getitem__(self,idx):
        '''Grabs relevant features from the dataset.'''
        if torch.is_tensor(idx):
            idx = idx.tolist()

        features = ['Timestamp', 'DLC', 'CAN_ID', 'Data']
        X_train = self.car_hacking_frame.loc[:, features].values
        X_train = torch.as_tensor(X_train)

        # It looks like it's a bad idea to encode features.
        # https://stackoverflow.com/questions/61217713/labelencoder-for-categorical-features

        y = self.car_hacking_frame['Flag'].iloc[idx]
        #y = torch.as_tensor(y)

        return X_train[idx], y
            
    def __len__(self):
        return len(self.car_hacking_frame)

class ValidationDataset(Dataset):
    def __init__(self, csv_file: str, root_dir: str, transform=None):
        self.validation_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __getitem__(self, idx):
        '''Grabs relevant features from the dataset.'''
        if torch.is_tensor(idx):
            idx = idx.tolist()

        features = ['Timestamp', 'DLC', 'CAN_ID', 'Data']
        X_train = self.validation_frame.loc[:, features].values
        X_train = torch.as_tensor(X_train, dtype=torch.float32)
        y = self.validation_frame['Flag'].iloc[idx]
        y = torch.as_tensor(y, dtype=torch.float32)

        return X_train[idx], y

    def __len__(self):
        return len(self.validation_frame)

train_dataset = CarHackingDataset(csv_file='/content/car_hacking_data/split_fuzzy_dataset_2_training_imbalanced.csv', 
                                  root_dir='/content/car_hacking_data')

test_loader = ValidationDataset(csv_file='/content/car_hacking_data/split_fuzzy_dataset_2_testing_imbalanced.csv', 
                                 root_dir='/content/car_hacking_data')

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

hook = sy.TorchHook(torch)

car1 = sy.VirtualWorker(hook, id="car1")
car2 = sy.VirtualWorker(hook, id="car2")

args = {
    'batch_size' : train_dataset.__len__(),
    'epochs' : 5
}

federated_train_loader = sy.FederatedDataLoader(train_dataset.federate((car1, car2)),
                                                batch_size=args['batch_size'], shuffle=True, drop_last=True)

# %%
import time
from sklearn.metrics import balanced_accuracy_score
import torch.nn as nn

def train(model, device, federated_train_loader, optimizer, epoch):
    model.train()

    for batch_idx, (data, target) in enumerate(federated_train_loader):
        model = model.send(data.location)

        data, target = data.reshape(args['batch_size'], 4, -1).to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)

        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        model.get()

        print(batch_idx)

        if batch_idx % 10 == 0:
            loss = loss.get()

            print(f'''Train Epoch: {epoch} [{(batch_idx * args['batch_size'])}/{(len(federated_train_loader) * args['batch_size'])}'''
                   + f'''({100. * batch_idx / len(federated_train_loader):.0f}%)]\tLoss: {loss.item():.6f}''')

def test(model, device, test_loader):
    model.eval()

    test_loss = 0
    correct = 0
    total = 0
    m = nn.Sigmoid()
    loss = nn.BCELoss()

    with torch.no_grad():
        for data, target in test_loader:
            #data, target = data.reshape(-1, 4, 1).to(device), target.to(device)
            data = data.reshape(-1, 1, 1).to(device)
            target = target.to(device)
            output = model(data)

            y = target.repeat(4, 1)
            test_loss += loss(m(data), y).item()

            #test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            # print(y.view_as(pred))
            y = y.reshape(4, 1)
            #correct += pred.eq(y.view_as(pred)).sum().item()
            total += y.size(0)
            correct += (pred == y).sum().item()

    test_loss /= len(test_loader)
    y = torch.as_tensor(y, dtype=torch.int8)

    print(f"The length of y is {len(y)}, shape of y is {y.shape}.")
    print(f"The pred is {len(pred)}, shape of pred is {pred.shape}")

    print(f"Test Loss: {test_loss}, Correct: {correct}, Accuracy: {100 * correct // total}%")

    '''print("\n Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n".format(
          test_loss, correct, test_loader.__len__,
          100. * correct/test_loader.__len__))'''

model = DeepESN(hidden_size=5000).to(device)

optimizer = optim.SGD(model.parameters(), lr=0.01)

t0 = time.time()
for epoch in range(1, args['batch_size'] + 1):
    train(model, device, federated_train_loader, optimizer, epoch)
t1 = time.time()

test(model, device, test_loader)
print(f'Training took {t1 - t0}s')
# Out:
# The length of y is 4, shape of y is torch.Size([4, 1]).
# The pred is 4, shape of pred is torch.Size([4, 1])
# Test Loss: 0.7534854360620181, Correct: 7836, Accuracy: 65%
# Training took 12.636591911315918s

# %%
import torch

test_loader = ValidationDataset(csv_file='/content/car_hacking_data/split_fuzzy_dataset_1_testing.csv', 
                                 root_dir='/content/car_hacking_data')

for data, target in test_loader:
  #print(f"OG Data: {data.reshape(-1, 1, 1)}, Target: {target}")
  print(data.reshape(-1, 1, 1))
  #print(target.size(0))
  #break
# Out:
# tensor([[[-0.5534]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.7168]]])
# tensor([[[-0.2782]],
#
#         [[ 0.1442]],
#
#         [[-1.0058]],
#
#         [[-0.5574]]])
# tensor([[[-0.8290]],
#
#         [[ 0.1442]],
#
#         [[-1.3635]],
#
#         [[ 0.2713]]])
# tensor([[[-0.2666]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9676]]])
# tensor([[[-0.2832]],
#
#         [[ 0.1442]],
#
#         [[-0.8021]],
#
#         [[ 2.0012]]])
# tensor([[[-0.4874]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.5554]]])
# tensor([[[ 0.0247]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.6860]]])
# tensor([[[ 0.0940]],
#
#         [[ 0.1442]],
#
#         [[-1.0248]],
#
#         [[ 1.7321]]])
# tensor([[[-0.2178]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.2304]]])
# tensor([[[-0.4169]],
#
#         [[ 0.1442]],
#
#         [[-1.0579]],
#
#         [[ 1.8224]]])
# tensor([[[ 0.1729]],
#
#         [[ 0.1442]],
#
#         [[-1.0271]],
#
#         [[ 2.0008]]])
# tensor([[[-0.1149]],
#
#         [[ 0.1442]],
#
#         [[-1.7591]],
#
#         [[-0.7289]]])
# tensor([[[ 0.0215]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9676]]])
# tensor([[[-0.0212]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.6485]]])
# tensor([[[-0.8070]],
#
#         [[ 0.1442]],
#
#         [[ 2.9715]],
#
#         [[-0.6915]]])
# tensor([[[-0.2094]],
#
#         [[ 0.1442]],
#
#         [[ 1.6473]],
#
#         [[-0.7289]]])
# tensor([[[-0.6964]],
#
#         [[ 0.1442]],
#
#         [[-1.0200]],
#
#         [[-0.4802]]])
# tensor([[[-0.3575]],
#
#         [[ 0.1442]],
#
#         [[-1.7591]],
#
#         [[-0.7266]]])
# tensor([[[-0.4282]],
#
#         [[ 0.1442]],
#
#         [[-1.3848]],
#
#         [[ 0.3168]]])
# tensor([[[-0.8589]],
#
#         [[ 0.1442]],
#
#         [[-1.3824]],
#
#         [[ 0.6063]]])
# tensor([[[0.0114]],
#
#         [[0.1442]],
#
#         [[0.1526]],
#
#         [[0.7157]]])
# tensor([[[-0.2223]],
#
#         [[ 0.1442]],
#
#         [[ 1.4317]],
#
#         [[ 1.5908]]])
# tensor([[[-0.3819]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4595]]])
# tensor([[[-1.0387]],
#
#         [[ 0.1442]],
#
#         [[ 0.1052]],
#
#         [[-0.3500]]])
# tensor([[[-0.2421]],
#
#         [[ 0.1442]],
#
#         [[-1.7591]],
#
#         [[-0.7289]]])
# tensor([[[-0.2123]],
#
#         [[ 0.1442]],
#
#         [[ 0.1455]],
#
#         [[-0.5634]]])
# tensor([[[-0.9198]],
#
#         [[ 0.1442]],
#
#         [[-1.0721]],
#
#         [[ 1.6745]]])
# tensor([[[-0.6580]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[-0.5893]],
#
#         [[ 0.1442]],
#
#         [[ 0.8395]],
#
#         [[ 1.9789]]])
# tensor([[[-0.0027]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[ 0.7155]]])
# tensor([[[-0.3401]],
#
#         [[ 0.1442]],
#
#         [[-1.0105]],
#
#         [[ 1.4108]]])
# tensor([[[-0.6699]],
#
#         [[ 0.1442]],
#
#         [[-1.0248]],
#
#         [[-0.4845]]])
# tensor([[[ 0.1821]],
#
#         [[ 0.1442]],
#
#         [[ 0.7756]],
#
#         [[-0.7289]]])
# tensor([[[-0.0658]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.3308]]])
# tensor([[[-0.2876]],
#
#         [[ 0.1442]],
#
#         [[-0.3094]],
#
#         [[-0.3433]]])
# tensor([[[-0.9099]],
#
#         [[ 0.1442]],
#
#         [[-1.0366]],
#
#         [[-0.3810]]])
# tensor([[[-0.3620]],
#
#         [[ 0.1442]],
#
#         [[ 3.0236]],
#
#         [[-0.2173]]])
# tensor([[[-1.0582]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[ 0.6965]]])
# tensor([[[-0.4021]],
#
#         [[ 0.1442]],
#
#         [[ 0.7756]],
#
#         [[-0.7289]]])
# tensor([[[-0.7724]],
#
#         [[ 0.1442]],
#
#         [[-1.0390]],
#
#         [[ 1.5057]]])
# tensor([[[-0.4647]],
#
#         [[ 0.1442]],
#
#         [[ 1.2304]],
#
#         [[-0.7236]]])
# tensor([[[-0.0749]],
#
#         [[ 0.1442]],
#
#         [[ 3.0331]],
#
#         [[-0.1928]]])
# tensor([[[-0.6762]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[ 2.0105]]])
# tensor([[[ 0.1684]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.0002]]])
# tensor([[[ 0.0165]],
#
#         [[ 0.1442]],
#
#         [[ 3.0307]],
#
#         [[-0.2239]]])
# tensor([[[ 0.0868]],
#
#         [[ 0.1442]],
#
#         [[-0.9608]],
#
#         [[-0.7276]]])
# tensor([[[ 0.1423]],
#
#         [[ 0.1442]],
#
#         [[-0.1696]],
#
#         [[-0.0411]]])
# tensor([[[-0.8938]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.4330]]])
# tensor([[[-0.4512]],
#
#         [[ 0.1442]],
#
#         [[-1.0153]],
#
#         [[ 1.7885]]])
# tensor([[[-0.0821]],
#
#         [[ 0.1442]],
#
#         [[-0.9608]],
#
#         [[-0.7276]]])
# tensor([[[-0.9615]],
#
#         [[ 0.1442]],
#
#         [[ 1.2304]],
#
#         [[-0.7289]]])
# tensor([[[ 0.1770]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8282]]])
# tensor([[[-0.8022]],
#
#         [[ 0.1442]],
#
#         [[ 0.2639]],
#
#         [[-0.6863]]])
# tensor([[[-0.8421]],
#
#         [[ 0.1442]],
#
#         [[ 0.1336]],
#
#         [[-0.3637]]])
# tensor([[[-0.8966]],
#
#         [[ 0.1442]],
#
#         [[-0.1814]],
#
#         [[-0.6825]]])
# tensor([[[-0.6800]],
#
#         [[ 0.1442]],
#
#         [[-0.3141]],
#
#         [[-0.4057]]])
# tensor([[[-0.5490]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.3308]]])
# tensor([[[-0.0610]],
#
#         [[ 0.1442]],
#
#         [[ 0.8135]],
#
#         [[ 2.0052]]])
# tensor([[[-1.0346]],
#
#         [[ 0.1442]],
#
#         [[-1.7591]],
#
#         [[-0.7289]]])
# tensor([[[-1.0809]],
#
#         [[ 0.1442]],
#
#         [[-0.5865]],
#
#         [[-0.6432]]])
# tensor([[[-0.5367]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.4877]]])
# tensor([[[-0.2834]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4164]]])
# tensor([[[-0.6965]],
#
#         [[ 0.1442]],
#
#         [[-0.5581]],
#
#         [[-0.6304]]])
# tensor([[[-0.1089]],
#
#         [[ 0.1442]],
#
#         [[-1.0579]],
#
#         [[-0.6833]]])
# tensor([[[ 0.0736]],
#
#         [[ 0.1442]],
#
#         [[-0.7973]],
#
#         [[ 2.0097]]])
# tensor([[[-0.1265]],
#
#         [[ 0.1442]],
#
#         [[-1.3990]],
#
#         [[ 0.2134]]])
# tensor([[[-0.3287]],
#
#         [[ 0.1442]],
#
#         [[-1.0555]],
#
#         [[-0.2151]]])
# tensor([[[-0.8485]],
#
#         [[ 0.1442]],
#
#         [[ 1.9008]],
#
#         [[-0.6842]]])
# tensor([[[-0.6625]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.7317]]])
# tensor([[[-0.1938]],
#
#         [[ 0.1442]],
#
#         [[ 2.9478]],
#
#         [[-0.6923]]])
# tensor([[[-1.0301]],
#
#         [[ 0.1442]],
#
#         [[-1.3967]],
#
#         [[ 0.6269]]])
# tensor([[[-0.1357]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[-0.2637]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4488]]])
# tensor([[[ 0.0174]],
#
#         [[ 0.1442]],
#
#         [[ 0.1431]],
#
#         [[-0.6846]]])
# tensor([[[-0.9106]],
#
#         [[ 0.1442]],
#
#         [[ 2.9715]],
#
#         [[-0.6915]]])
# tensor([[[-0.0200]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.4984]]])
# tensor([[[-0.0512]],
#
#         [[ 0.1442]],
#
#         [[-0.5439]],
#
#         [[-0.6265]]])
# tensor([[[-0.0726]],
#
#         [[ 0.1442]],
#
#         [[-1.7591]],
#
#         [[-0.7289]]])
# tensor([[[ 0.0731]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.6592]]])
# tensor([[[-0.0647]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.2304]]])
# tensor([[[-3.0415e-01]],
#
#         [[ 1.4421e-01]],
#
#         [[-1.7197e-01]],
#
#         [[ 1.8501e-04]]])
# tensor([[[-0.8524]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[-0.7557]],
#
#         [[ 0.1442]],
#
#         [[-1.0200]],
#
#         [[ 1.4960]]])
# tensor([[[ 0.0170]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.2304]]])
# tensor([[[-0.1725]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.3429]]])
# tensor([[[-0.8241]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[ 1.6491]]])
# tensor([[[-0.6038]],
#
#         [[ 0.1442]],
#
#         [[-1.0674]],
#
#         [[ 1.9795]]])
# tensor([[[-0.3287]],
#
#         [[ 0.1442]],
#
#         [[-0.8116]],
#
#         [[ 1.9879]]])
# tensor([[[ 0.1046]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.3429]]])
# tensor([[[-0.5618]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8282]]])
# tensor([[[-0.7985]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.6700]]])
# tensor([[[-0.0212]],
#
#         [[ 0.1442]],
#
#         [[-1.0650]],
#
#         [[ 1.6231]]])
# tensor([[[ 0.1643]],
#
#         [[ 0.1442]],
#
#         [[ 0.1336]],
#
#         [[-0.5945]]])
# tensor([[[-0.5525]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6739]]])
# tensor([[[-0.6890]],
#
#         [[ 0.1442]],
#
#         [[-1.0319]],
#
#         [[ 1.8663]]])
# tensor([[[-0.3128]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9676]]])
# tensor([[[-0.2961]],
#
#         [[ 0.1442]],
#
#         [[-1.3848]],
#
#         [[ 0.3165]]])
# tensor([[[-1.0001]],
#
#         [[ 0.1442]],
#
#         [[ 0.8111]],
#
#         [[-0.7262]]])
# tensor([[[-0.2928]],
#
#         [[ 0.1442]],
#
#         [[ 1.0598]],
#
#         [[-0.3034]]])
# tensor([[[-0.8144]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.5816]]])
# tensor([[[-0.0471]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.6860]]])
# tensor([[[-0.3043]],
#
#         [[ 0.1442]],
#
#         [[ 1.4317]],
#
#         [[ 1.5908]]])
# tensor([[[-0.4349]],
#
#         [[ 0.1442]],
#
#         [[ 0.8135]],
#
#         [[ 1.9763]]])
# tensor([[[-0.1952]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6739]]])
# tensor([[[-0.5332]],
#
#         [[ 0.1442]],
#
#         [[ 0.7756]],
#
#         [[-0.7289]]])
# tensor([[[-0.6268]],
#
#         [[ 0.1442]],
#
#         [[ 2.1779]],
#
#         [[-0.7066]]])
# tensor([[[-0.1463]],
#
#         [[ 0.1442]],
#
#         [[ 0.2449]],
#
#         [[-0.6740]]])
# tensor([[[-0.0957]],
#
#         [[ 0.1442]],
#
#         [[-1.0366]],
#
#         [[ 1.6568]]])
# tensor([[[-0.0293]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.3433]]])
# tensor([[[-0.4790]],
#
#         [[ 0.1442]],
#
#         [[-0.9608]],
#
#         [[-0.7276]]])
# tensor([[[-0.3284]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.3433]]])
# tensor([[[-0.9509]],
#
#         [[ 0.1442]],
#
#         [[-1.0650]],
#
#         [[ 1.9325]]])
# tensor([[[-0.8972]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6738]]])
# tensor([[[-0.5609]],
#
#         [[ 0.1442]],
#
#         [[-1.3848]],
#
#         [[ 0.2415]]])
# tensor([[[-0.5467]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.3161]]])
# tensor([[[-0.4516]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[-0.7234]],
#
#         [[ 0.1442]],
#
#         [[ 1.0906]],
#
#         [[-0.2750]]])
# tensor([[[-0.4179]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.3433]]])
# tensor([[[-0.9066]],
#
#         [[ 0.1442]],
#
#         [[-1.0484]],
#
#         [[-0.0819]]])
# tensor([[[-0.9643]],
#
#         [[ 0.1442]],
#
#         [[ 1.6212]],
#
#         [[-0.7237]]])
# tensor([[[-0.1950]],
#
#         [[ 0.1442]],
#
#         [[-1.3753]],
#
#         [[ 0.6937]]])
# tensor([[[-0.3133]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6739]]])
# tensor([[[-0.3365]],
#
#         [[ 0.1442]],
#
#         [[ 1.2304]],
#
#         [[-0.7289]]])
# tensor([[[-0.7755]],
#
#         [[ 0.1442]],
#
#         [[-1.0105]],
#
#         [[-0.6547]]])
# tensor([[[-0.8963]],
#
#         [[ 0.1442]],
#
#         [[-1.3896]],
#
#         [[ 0.5998]]])
# tensor([[[-0.8133]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.1275]]])
# tensor([[[-0.2089]],
#
#         [[ 0.1442]],
#
#         [[-1.3824]],
#
#         [[ 0.6171]]])
# tensor([[[-0.9017]],
#
#         [[ 0.1442]],
#
#         [[-1.0508]],
#
#         [[ 1.7618]]])
# tensor([[[-0.0156]],
#
#         [[ 0.1442]],
#
#         [[-1.3990]],
#
#         [[ 0.6104]]])
# tensor([[[ 0.1047]],
#
#         [[ 0.1442]],
#
#         [[-1.3824]],
#
#         [[ 0.6492]]])
# tensor([[[-0.1138]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9247]]])
# tensor([[[-0.5438]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[-0.4174]],
#
#         [[ 0.1442]],
#
#         [[-1.0271]],
#
#         [[ 1.8701]]])
# tensor([[[-0.6865]],
#
#         [[ 0.1442]],
#
#         [[-0.8187]],
#
#         [[ 2.0051]]])
# tensor([[[-0.7243]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.0204]]])
# tensor([[[-0.0171]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.3161]]])
# tensor([[[-0.7369]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4273]]])
# tensor([[[ 0.1446]],
#
#         [[ 0.1442]],
#
#         [[ 1.2304]],
#
#         [[-0.7289]]])
# tensor([[[-0.8267]],
#
#         [[ 0.1442]],
#
#         [[ 1.2304]],
#
#         [[-0.7289]]])
# tensor([[[-0.0874]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4702]]])
# tensor([[[-0.8255]],
#
#         [[ 0.1442]],
#
#         [[ 0.8253]],
#
#         [[ 1.9812]]])
# tensor([[[-0.9633]],
#
#         [[ 0.1442]],
#
#         [[ 1.0811]],
#
#         [[-0.2877]]])
# tensor([[[-0.0064]],
#
#         [[ 0.1442]],
#
#         [[-0.8187]],
#
#         [[ 1.9981]]])
# tensor([[[0.0598]],
#
#         [[0.1442]],
#
#         [[1.4341]],
#
#         [[1.6694]]])
# tensor([[[-0.2120]],
#
#         [[ 0.1442]],
#
#         [[-1.3706]],
#
#         [[ 0.6608]]])
# tensor([[[-0.6491]],
#
#         [[ 0.1442]],
#
#         [[-1.0366]],
#
#         [[-0.4556]]])
# tensor([[[-0.6964]],
#
#         [[ 0.1442]],
#
#         [[-1.0603]],
#
#         [[ 1.9421]]])
# tensor([[[-0.9480]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[-0.0415]],
#
#         [[ 0.1442]],
#
#         [[ 2.2466]],
#
#         [[-0.6970]]])
# tensor([[[-0.5319]],
#
#         [[ 0.1442]],
#
#         [[-1.0579]],
#
#         [[-0.2281]]])
# tensor([[[-1.0043]],
#
#         [[ 0.1442]],
#
#         [[-1.0105]],
#
#         [[ 1.7308]]])
# tensor([[[-0.1004]],
#
#         [[ 0.1442]],
#
#         [[-0.5534]],
#
#         [[-0.6367]]])
# tensor([[[-0.4570]],
#
#         [[ 0.1442]],
#
#         [[ 2.9975]],
#
#         [[-0.1866]]])
# tensor([[[-0.4823]],
#
#         [[ 0.1442]],
#
#         [[-0.1909]],
#
#         [[-0.3536]]])
# tensor([[[-1.0582]],
#
#         [[ 0.1442]],
#
#         [[ 0.2473]],
#
#         [[-0.6963]]])
# tensor([[[-0.7736]],
#
#         [[ 0.1442]],
#
#         [[ 0.8135]],
#
#         [[ 2.0052]]])
# tensor([[[-0.5395]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.6056]]])
# tensor([[[-1.0148]],
#
#         [[ 0.1442]],
#
#         [[-1.0200]],
#
#         [[-0.6456]]])
# tensor([[[-0.0140]],
#
#         [[ 0.1442]],
#
#         [[ 1.2256]],
#
#         [[-0.6852]]])
# tensor([[[-0.2863]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[-0.2347]],
#
#         [[ 0.1442]],
#
#         [[ 1.1167]],
#
#         [[-0.3005]]])
# tensor([[[-0.1507]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.5923]]])
# tensor([[[ 0.0844]],
#
#         [[ 0.1442]],
#
#         [[-0.0962]],
#
#         [[-0.5145]]])
# tensor([[[-0.6476]],
#
#         [[ 0.1442]],
#
#         [[-0.1933]],
#
#         [[-0.3530]]])
# tensor([[[-0.4526]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[-0.5852]],
#
#         [[ 0.1442]],
#
#         [[-1.0011]],
#
#         [[-0.5317]]])
# tensor([[[-0.6426]],
#
#         [[ 0.1442]],
#
#         [[-1.0698]],
#
#         [[-0.6940]]])
# tensor([[[-0.3257]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.3483]]])
# tensor([[[-0.8222]],
#
#         [[ 0.1442]],
#
#         [[-1.0366]],
#
#         [[ 1.7606]]])
# tensor([[[-0.8697]],
#
#         [[ 0.1442]],
#
#         [[ 0.1668]],
#
#         [[-0.0521]]])
# tensor([[[-0.9855]],
#
#         [[ 0.1442]],
#
#         [[ 0.1834]],
#
#         [[ 0.7228]]])
# tensor([[[-0.5629]],
#
#         [[ 0.1442]],
#
#         [[ 0.2331]],
#
#         [[-0.6581]]])
# tensor([[[-0.7244]],
#
#         [[ 0.1442]],
#
#         [[-0.0962]],
#
#         [[-0.5145]]])
# tensor([[[ 7.7101e-04]],
#
#         [[ 1.4421e-01]],
#
#         [[-1.0437e+00]],
#
#         [[-5.6275e-01]]])
# tensor([[[-0.9131]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8282]]])
# tensor([[[-0.3785]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.6245]]])
# tensor([[[-0.3018]],
#
#         [[ 0.1442]],
#
#         [[ 1.6283]],
#
#         [[-0.6624]]])
# tensor([[[-0.6881]],
#
#         [[ 0.1442]],
#
#         [[ 1.6544]],
#
#         [[-0.6924]]])
# tensor([[[-1.0884]],
#
#         [[ 0.1442]],
#
#         [[ 0.1336]],
#
#         [[ 1.6156]]])
# tensor([[[-0.0593]],
#
#         [[ 0.1442]],
#
#         [[-1.0532]],
#
#         [[-0.4951]]])
# tensor([[[-0.9479]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.3429]]])
# tensor([[[ 0.1371]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6739]]])
# tensor([[[ 0.0689]],
#
#         [[ 0.1442]],
#
#         [[-1.0627]],
#
#         [[-0.5244]]])
# tensor([[[-0.9006]],
#
#         [[ 0.1442]],
#
#         [[ 0.1170]],
#
#         [[-0.3370]]])
# tensor([[[-0.9969]],
#
#         [[ 0.1442]],
#
#         [[ 0.1502]],
#
#         [[-0.0105]]])
# tensor([[[-0.9557]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6739]]])
# tensor([[[-0.9196]],
#
#         [[ 0.1442]],
#
#         [[-0.8163]],
#
#         [[ 2.0070]]])
# tensor([[[-0.7417]],
#
#         [[ 0.1442]],
#
#         [[ 0.3207]],
#
#         [[-0.7276]]])
# tensor([[[-0.9703]],
#
#         [[ 0.1442]],
#
#         [[-1.0200]],
#
#         [[-0.5760]]])
# tensor([[[ 0.0629]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8711]]])
# tensor([[[-1.1148]],
#
#         [[ 0.1442]],
#
#         [[ 0.1573]],
#
#         [[ 1.6513]]])
# tensor([[[-0.5858]],
#
#         [[ 0.1442]],
#
#         [[ 0.0933]],
#
#         [[-0.3258]]])
# tensor([[[-0.6647]],
#
#         [[ 0.1442]],
#
#         [[ 1.6591]],
#
#         [[-0.7260]]])
# tensor([[[-0.3401]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6738]]])
# tensor([[[-0.1939]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8711]]])
# tensor([[[-0.4815]],
#
#         [[ 0.1442]],
#
#         [[-1.0248]],
#
#         [[ 1.8741]]])
# tensor([[[-0.5275]],
#
#         [[ 0.1442]],
#
#         [[-1.0058]],
#
#         [[-0.7182]]])
# tensor([[[-0.2399]],
#
#         [[ 0.1442]],
#
#         [[-0.3567]],
#
#         [[-0.4638]]])
# tensor([[[ 0.1451]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.6056]]])
# tensor([[[-0.4874]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.3023]]])
# tensor([[[-0.8919]],
#
#         [[ 0.1442]],
#
#         [[-1.4109]],
#
#         [[ 0.2929]]])
# tensor([[[-0.3569]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.5280]]])
# tensor([[[-0.0474]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[ 1.6379]]])
# tensor([[[ 0.0631]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.1875]]])
# tensor([[[-0.5618]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8071]]])
# tensor([[[-0.5842]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[-1.1124]],
#
#         [[ 0.1442]],
#
#         [[-0.8187]],
#
#         [[ 1.9982]]])
# tensor([[[ 0.1107]],
#
#         [[ 0.1442]],
#
#         [[-0.5865]],
#
#         [[-0.6432]]])
# tensor([[[-0.2757]],
#
#         [[ 0.1442]],
#
#         [[ 1.0811]],
#
#         [[-0.2877]]])
# tensor([[[-0.5798]],
#
#         [[ 0.1442]],
#
#         [[-1.0366]],
#
#         [[ 1.5334]]])
# tensor([[[-0.3462]],
#
#         [[ 0.1442]],
#
#         [[ 0.1360]],
#
#         [[ 0.7549]]])
# tensor([[[-0.2970]],
#
#         [[ 0.1442]],
#
#         [[ 1.0811]],
#
#         [[-0.2877]]])
# tensor([[[-0.0250]],
#
#         [[ 0.1442]],
#
#         [[-1.0484]],
#
#         [[ 1.4123]]])
# tensor([[[-1.0224]],
#
#         [[ 0.1442]],
#
#         [[-1.0603]],
#
#         [[-0.4486]]])
# tensor([[[-0.6002]],
#
#         [[ 0.1442]],
#
#         [[-1.3824]],
#
#         [[ 0.5956]]])
# tensor([[[-0.6256]],
#
#         [[ 0.1442]],
#
#         [[-1.0319]],
#
#         [[ 1.6300]]])
# tensor([[[-0.3148]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9247]]])
# tensor([[[-0.4523]],
#
#         [[ 0.1442]],
#
#         [[-0.1672]],
#
#         [[ 0.3534]]])
# tensor([[[-0.4173]],
#
#         [[ 0.1442]],
#
#         [[-1.0366]],
#
#         [[-0.2799]]])
# tensor([[[-0.3851]],
#
#         [[ 0.1442]],
#
#         [[-1.0721]],
#
#         [[-0.6516]]])
# tensor([[[-0.1505]],
#
#         [[ 0.1442]],
#
#         [[ 0.8135]],
#
#         [[ 2.0052]]])
# tensor([[[-0.1150]],
#
#         [[ 0.1442]],
#
#         [[-0.8187]],
#
#         [[ 1.9981]]])
# tensor([[[-0.0345]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.6860]]])
# tensor([[[-0.2944]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.3054]]])
# tensor([[[-1.0237]],
#
#         [[ 0.1442]],
#
#         [[ 0.0981]],
#
#         [[-0.6577]]])
# tensor([[[-0.3060]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.5927]]])
# tensor([[[-0.1261]],
#
#         [[ 0.1442]],
#
#         [[ 0.1478]],
#
#         [[ 0.6995]]])
# tensor([[[-0.5047]],
#
#         [[ 0.1442]],
#
#         [[ 0.1336]],
#
#         [[-0.0584]]])
# tensor([[[-0.4525]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[ 0.0621]],
#
#         [[ 0.1442]],
#
#         [[ 0.8111]],
#
#         [[-0.7262]]])
# tensor([[[-0.0929]],
#
#         [[ 0.1442]],
#
#         [[-1.0058]],
#
#         [[-0.5467]]])
# tensor([[[-0.1486]],
#
#         [[ 0.1442]],
#
#         [[-1.3824]],
#
#         [[ 0.6599]]])
# tensor([[[-0.2884]],
#
#         [[ 0.1442]],
#
#         [[-1.0461]],
#
#         [[-0.7072]]])
# tensor([[[ 0.0883]],
#
#         [[ 0.1442]],
#
#         [[ 1.2233]],
#
#         [[-0.7147]]])
# tensor([[[-0.8176]],
#
#         [[ 0.1442]],
#
#         [[-1.4085]],
#
#         [[ 0.3028]]])
# tensor([[[-0.1315]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9247]]])
# tensor([[[-0.5889]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.0601]]])
# tensor([[[-1.1129]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8282]]])
# tensor([[[-0.7958]],
#
#         [[ 0.1442]],
#
#         [[ 1.4317]],
#
#         [[ 1.5908]]])
# tensor([[[ 0.0728]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.7129]]])
# tensor([[[-0.7483]],
#
#         [[ 0.1442]],
#
#         [[ 1.4317]],
#
#         [[ 1.5909]]])
# tensor([[[-1.0586]],
#
#         [[ 0.1442]],
#
#         [[-0.1862]],
#
#         [[-0.0031]]])
# tensor([[[ 0.0668]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.3646]]])
# tensor([[[ 0.1423]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.0002]]])
# tensor([[[-0.9208]],
#
#         [[ 0.1442]],
#
#         [[ 2.9715]],
#
#         [[-0.6915]]])
# tensor([[[ 0.0618]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[ 1.6788]]])
# tensor([[[-0.6922]],
#
#         [[ 0.1442]],
#
#         [[-0.1862]],
#
#         [[-0.0101]]])
# tensor([[[-0.2795]],
#
#         [[ 0.1442]],
#
#         [[-0.0938]],
#
#         [[-0.4870]]])
# tensor([[[-0.9154]],
#
#         [[ 0.1442]],
#
#         [[ 2.1945]],
#
#         [[-0.7201]]])
# tensor([[[ 0.1327]],
#
#         [[ 0.1442]],
#
#         [[-1.4061]],
#
#         [[ 0.3586]]])
# tensor([[[-0.1749]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.5924]]])
# tensor([[[-0.4840]],
#
#         [[ 0.1442]],
#
#         [[ 0.1620]],
#
#         [[-0.0245]]])
# tensor([[[-1.0716]],
#
#         [[ 0.1442]],
#
#         [[-1.7591]],
#
#         [[-0.7289]]])
# tensor([[[-0.1940]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9247]]])
# tensor([[[-0.5304]],
#
#         [[ 0.1442]],
#
#         [[-1.3588]],
#
#         [[ 0.6592]]])
# tensor([[[-0.1050]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[ 0.1442]],
#
#         [[ 0.1442]],
#
#         [[-1.7591]],
#
#         [[-0.7289]]])
# tensor([[[-1.0632]],
#
#         [[ 0.1442]],
#
#         [[-1.0390]],
#
#         [[ 1.8059]]])
# tensor([[[-0.3735]],
#
#         [[ 0.1442]],
#
#         [[ 2.9833]],
#
#         [[-0.2164]]])
# tensor([[[-0.2743]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.3737]]])
# tensor([[[-0.6929]],
#
#         [[ 0.1442]],
#
#         [[-1.4014]],
#
#         [[ 0.2376]]])
# tensor([[[-0.3807]],
#
#         [[ 0.1442]],
#
#         [[ 1.6449]],
#
#         [[-0.6693]]])
# tensor([[[-0.2538]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.3805]]])
# tensor([[[-0.0068]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.1875]]])
# tensor([[[-0.3152]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.3429]]])
# tensor([[[-1.0679]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.5199]]])
# tensor([[[-0.2793]],
#
#         [[ 0.1442]],
#
#         [[ 0.2449]],
#
#         [[-0.6740]]])
# tensor([[[-0.6020]],
#
#         [[ 0.1442]],
#
#         [[-1.3824]],
#
#         [[ 0.6599]]])
# tensor([[[-0.9377]],
#
#         [[ 0.1442]],
#
#         [[ 0.0910]],
#
#         [[-0.6568]]])
# tensor([[[-0.4268]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[ 0.7158]]])
# tensor([[[ 0.0991]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.6781]]])
# tensor([[[ 0.1186]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.5924]]])
# tensor([[[-0.9615]],
#
#         [[ 0.1442]],
#
#         [[ 0.7756]],
#
#         [[-0.7289]]])
# tensor([[[-0.2145]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.3269]]])
# tensor([[[-0.7358]],
#
#         [[ 0.1442]],
#
#         [[-0.9608]],
#
#         [[-0.7276]]])
# tensor([[[-0.6481]],
#
#         [[ 0.1442]],
#
#         [[-1.0153]],
#
#         [[-0.5606]]])
# tensor([[[-1.1285]],
#
#         [[ 0.1442]],
#
#         [[ 2.2182]],
#
#         [[-0.6888]]])
# tensor([[[-0.5893]],
#
#         [[ 0.1442]],
#
#         [[ 0.8135]],
#
#         [[ 2.0052]]])
# tensor([[[ 0.0234]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.5816]]])
# tensor([[[ 0.1355]],
#
#         [[ 0.1442]],
#
#         [[ 2.9881]],
#
#         [[-0.6743]]])
# tensor([[[-1.0634]],
#
#         [[ 0.1442]],
#
#         [[ 0.3207]],
#
#         [[-0.7276]]])
# tensor([[[-0.2795]],
#
#         [[ 0.1442]],
#
#         [[ 0.2449]],
#
#         [[-0.6740]]])
# tensor([[[-0.6214]],
#
#         [[ 0.1442]],
#
#         [[-1.3706]],
#
#         [[ 0.5825]]])
# tensor([[[-0.5321]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.0347]]])
# tensor([[[-0.4129]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.5816]]])
# tensor([[[-0.2874]],
#
#         [[ 0.1442]],
#
#         [[-1.0390]],
#
#         [[ 1.4517]]])
# tensor([[[-0.1530]],
#
#         [[ 0.1442]],
#
#         [[ 0.1715]],
#
#         [[ 0.7229]]])
# tensor([[[-0.5399]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.6860]]])
# tensor([[[-0.7055]],
#
#         [[ 0.1442]],
#
#         [[-1.0366]],
#
#         [[-0.3653]]])
# tensor([[[-0.1042]],
#
#         [[ 0.1442]],
#
#         [[-1.0105]],
#
#         [[-0.4102]]])
# tensor([[[-0.9751]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9247]]])
# tensor([[[-0.1750]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.5520]]])
# tensor([[[ 0.0517]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9247]]])
# tensor([[[-0.2636]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4488]]])
# tensor([[[-0.3029]],
#
#         [[ 0.1442]],
#
#         [[ 1.6520]],
#
#         [[-0.6860]]])
# tensor([[[-0.0294]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.3433]]])
# tensor([[[-1.0234]],
#
#         [[ 0.1442]],
#
#         [[ 1.6473]],
#
#         [[-0.7289]]])
# tensor([[[-0.6380]],
#
#         [[ 0.1442]],
#
#         [[ 0.3065]],
#
#         [[-0.7212]]])
# tensor([[[ 0.0738]],
#
#         [[ 0.1442]],
#
#         [[-1.3943]],
#
#         [[ 0.6960]]])
# tensor([[[-0.1558]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8711]]])
# tensor([[[ 0.1105]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9247]]])
# tensor([[[-1.1136]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.5280]]])
# tensor([[[-0.2442]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.5923]]])
# tensor([[[-0.2874]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.3308]]])
# tensor([[[-0.9477]],
#
#         [[ 0.1442]],
#
#         [[-1.0058]],
#
#         [[-0.5467]]])
# tensor([[[-1.1422]],
#
#         [[ 0.1442]],
#
#         [[-0.8187]],
#
#         [[ 1.9981]]])
# tensor([[[-0.7022]],
#
#         [[ 0.1442]],
#
#         [[ 0.1597]],
#
#         [[-0.5881]]])
# tensor([[[-0.2015]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[-1.1156]],
#
#         [[ 0.1442]],
#
#         [[-0.3259]],
#
#         [[-0.4025]]])
# tensor([[[ 0.0468]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.3698]]])
# tensor([[[-0.3075]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.2840]]])
# tensor([[[ 0.0445]],
#
#         [[ 0.1442]],
#
#         [[-0.1530]],
#
#         [[-0.7123]]])
# tensor([[[-0.5051]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.0790]]])
# tensor([[[-0.7333]],
#
#         [[ 0.1442]],
#
#         [[-1.0153]],
#
#         [[-0.4727]]])
# tensor([[[-0.5731]],
#
#         [[ 0.1442]],
#
#         [[ 0.2473]],
#
#         [[-0.6738]]])
# tensor([[[0.0750]],
#
#         [[0.1442]],
#
#         [[1.4317]],
#
#         [[1.5910]]])
# tensor([[[-0.9836]],
#
#         [[ 0.1442]],
#
#         [[-1.7401]],
#
#         [[-0.7112]]])
# tensor([[[-0.6845]],
#
#         [[ 0.1442]],
#
#         [[-0.0962]],
#
#         [[-0.5145]]])
# tensor([[[-0.7806]],
#
#         [[ 0.1442]],
#
#         [[ 1.6260]],
#
#         [[-0.6895]]])
# tensor([[[-0.2124]],
#
#         [[ 0.1442]],
#
#         [[-1.0129]],
#
#         [[-0.3003]]])
# tensor([[[-0.1108]],
#
#         [[ 0.1442]],
#
#         [[-0.1933]],
#
#         [[-0.3429]]])
# tensor([[[-0.4529]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.7746]]])
# tensor([[[ 0.1532]],
#
#         [[ 0.1442]],
#
#         [[-1.3753]],
#
#         [[ 0.2743]]])
# tensor([[[-0.3491]],
#
#         [[ 0.1442]],
#
#         [[-1.3824]],
#
#         [[ 0.6599]]])
# tensor([[[-0.1666]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.0002]]])
# tensor([[[-0.0928]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.3433]]])
# tensor([[[-0.7001]],
#
#         [[ 0.1442]],
#
#         [[-1.3445]],
#
#         [[ 0.6135]]])
# tensor([[[-0.6620]],
#
#         [[ 0.1442]],
#
#         [[ 0.2355]],
#
#         [[-0.6528]]])
# tensor([[[ 0.0513]],
#
#         [[ 0.1442]],
#
#         [[-1.0745]],
#
#         [[-0.2653]]])
# tensor([[[-1.1148]],
#
#         [[ 0.1442]],
#
#         [[ 1.2304]],
#
#         [[-0.6701]]])
# tensor([[[-0.6166]],
#
#         [[ 0.1442]],
#
#         [[ 1.6307]],
#
#         [[-0.7220]]])
# tensor([[[-0.3584]],
#
#         [[ 0.1442]],
#
#         [[-1.3848]],
#
#         [[ 0.3167]]])
# tensor([[[-0.5819]],
#
#         [[ 0.1442]],
#
#         [[ 1.0811]],
#
#         [[-0.2877]]])
# tensor([[[ 0.1383]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[ 1.9891]]])
# tensor([[[ 0.0845]],
#
#         [[ 0.1442]],
#
#         [[-0.0962]],
#
#         [[-0.5145]]])
# tensor([[[-1.0321]],
#
#         [[ 0.1442]],
#
#         [[-1.0603]],
#
#         [[ 1.3422]]])
# tensor([[[-0.9007]],
#
#         [[ 0.1442]],
#
#         [[-0.8163]],
#
#         [[ 1.9979]]])
# tensor([[[-0.2219]],
#
#         [[ 0.1442]],
#
#         [[ 2.9715]],
#
#         [[-0.6915]]])
# tensor([[[-0.3632]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6739]]])
# tensor([[[-1.1202]],
#
#         [[ 0.1442]],
#
#         [[-1.7591]],
#
#         [[-0.7289]]])
# tensor([[[ 0.0159]],
#
#         [[ 0.1442]],
#
#         [[ 2.2158]],
#
#         [[-0.7289]]])
# tensor([[[-1.0993]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.3590]]])
# tensor([[[-0.4115]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.6860]]])
# tensor([[[-0.0993]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8711]]])
# tensor([[[-0.1855]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.6164]]])
# tensor([[[-0.6044]],
#
#         [[ 0.1442]],
#
#         [[-1.0366]],
#
#         [[-0.4818]]])
# tensor([[[ 0.1862]],
#
#         [[ 0.1442]],
#
#         [[-0.2952]],
#
#         [[-0.4656]]])
# tensor([[[-0.4517]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.0348]]])
# tensor([[[-1.0276]],
#
#         [[ 0.1442]],
#
#         [[ 0.1147]],
#
#         [[-0.3843]]])
# tensor([[[-0.3317]],
#
#         [[ 0.1442]],
#
#         [[ 0.8111]],
#
#         [[-0.7262]]])
# tensor([[[-0.6885]],
#
#         [[ 0.1442]],
#
#         [[ 0.2520]],
#
#         [[-0.6525]]])
# tensor([[[-0.6380]],
#
#         [[ 0.1442]],
#
#         [[ 0.3207]],
#
#         [[-0.7276]]])
# tensor([[[-0.2841]],
#
#         [[ 0.1442]],
#
#         [[ 1.4317]],
#
#         [[ 1.5870]]])
# tensor([[[-0.0590]],
#
#         [[ 0.1442]],
#
#         [[ 1.2612]],
#
#         [[-0.6973]]])
# tensor([[[-1.0058]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.6781]]])
# tensor([[[-1.1310]],
#
#         [[ 0.1442]],
#
#         [[ 1.6520]],
#
#         [[-0.6753]]])
# tensor([[[-0.0596]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8282]]])
# tensor([[[-0.3961]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.4019]]])
# tensor([[[ 0.0939]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.3308]]])
# tensor([[[-0.0338]],
#
#         [[ 0.1442]],
#
#         [[-1.0271]],
#
#         [[ 1.5210]]])
# tensor([[[-0.4654]],
#
#         [[ 0.1442]],
#
#         [[ 0.1170]],
#
#         [[-0.6530]]])
# tensor([[[-0.2070]],
#
#         [[ 0.1442]],
#
#         [[ 0.3207]],
#
#         [[-0.7276]]])
# tensor([[[-0.1751]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.5520]]])
# tensor([[[-0.8430]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.7129]]])
# tensor([[[-0.3443]],
#
#         [[ 0.1442]],
#
#         [[-1.4014]],
#
#         [[ 0.3101]]])
# tensor([[[-0.4526]],
#
#         [[ 0.1442]],
#
#         [[-1.0792]],
#
#         [[-0.6893]]])
# tensor([[[-0.8260]],
#
#         [[ 0.1442]],
#
#         [[-1.0176]],
#
#         [[-0.7115]]])
# tensor([[[-1.0589]],
#
#         [[ 0.1442]],
#
#         [[-0.8187]],
#
#         [[ 1.9981]]])
# tensor([[[-0.3497]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[ 1.6378]]])
# tensor([[[-1.0663]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[ 1.6375]]])
# tensor([[[ 0.0702]],
#
#         [[ 0.1442]],
#
#         [[-1.0034]],
#
#         [[-0.3825]]])
# tensor([[[-0.1137]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.6781]]])
# tensor([[[-0.8336]],
#
#         [[ 0.1442]],
#
#         [[-0.9703]],
#
#         [[-0.7262]]])
# tensor([[[-1.0516]],
#
#         [[ 0.1442]],
#
#         [[-1.3824]],
#
#         [[ 0.6707]]])
# tensor([[[-0.0742]],
#
#         [[ 0.1442]],
#
#         [[-0.0962]],
#
#         [[-0.5262]]])
# tensor([[[-0.5308]],
#
#         [[ 0.1442]],
#
#         [[ 0.1691]],
#
#         [[-0.5693]]])
# tensor([[[-0.3243]],
#
#         [[ 0.1442]],
#
#         [[-1.0248]],
#
#         [[ 1.6328]]])
# tensor([[[-0.6643]],
#
#         [[ 0.1442]],
#
#         [[-1.0555]],
#
#         [[-0.3780]]])
# tensor([[[ 0.1355]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.7746]]])
# tensor([[[-0.6580]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.4840]]])
# tensor([[[-0.5039]],
#
#         [[ 0.1442]],
#
#         [[-1.0555]],
#
#         [[-0.6216]]])
# tensor([[[-0.5553]],
#
#         [[ 0.1442]],
#
#         [[-1.4156]],
#
#         [[ 0.3317]]])
# tensor([[[ 0.0536]],
#
#         [[ 0.1442]],
#
#         [[-1.7259]],
#
#         [[-0.7044]]])
# tensor([[[-1.0442]],
#
#         [[ 0.1442]],
#
#         [[ 1.6141]],
#
#         [[-0.7273]]])
# tensor([[[-0.2667]],
#
#         [[ 0.1442]],
#
#         [[-0.9750]],
#
#         [[-0.5594]]])
# tensor([[[ 0.0738]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.7746]]])
# tensor([[[-0.7004]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.5198]]])
# tensor([[[-0.6490]],
#
#         [[ 0.1442]],
#
#         [[-0.1649]],
#
#         [[ 0.0019]]])
# tensor([[[-0.0397]],
#
#         [[ 0.1442]],
#
#         [[ 1.6520]],
#
#         [[-0.6860]]])
# tensor([[[-0.8379]],
#
#         [[ 0.1442]],
#
#         [[-1.0627]],
#
#         [[ 1.8309]]])
# tensor([[[-0.8737]],
#
#         [[ 0.1442]],
#
#         [[-1.3848]],
#
#         [[ 0.2629]]])
# tensor([[[-0.9639]],
#
#         [[ 0.1442]],
#
#         [[ 0.1123]],
#
#         [[ 0.7172]]])
# tensor([[[-0.4284]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4058]]])
# tensor([[[-0.1003]],
#
#         [[ 0.1442]],
#
#         [[ 0.2449]],
#
#         [[-0.6740]]])
# tensor([[[ 0.0969]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.3429]]])
# tensor([[[ 0.1105]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.3429]]])
# tensor([[[-0.7425]],
#
#         [[ 0.1442]],
#
#         [[-0.8258]],
#
#         [[ 2.0131]]])
# tensor([[[-0.6465]],
#
#         [[ 0.1442]],
#
#         [[-0.1767]],
#
#         [[ 0.3268]]])
# tensor([[[-0.7331]],
#
#         [[ 0.1442]],
#
#         [[-1.0342]],
#
#         [[-0.4032]]])
# tensor([[[-0.8862]],
#
#         [[ 0.1442]],
#
#         [[-0.1009]],
#
#         [[-0.5114]]])
# tensor([[[-0.8931]],
#
#         [[ 0.1442]],
#
#         [[-0.8092]],
#
#         [[ 2.0114]]])
# tensor([[[-0.6737]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[ 1.9998]]])
# tensor([[[-0.8028]],
#
#         [[ 0.1442]],
#
#         [[ 0.7874]],
#
#         [[ 1.9956]]])
# tensor([[[ 0.0913]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.7746]]])
# tensor([[[-0.3609]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.5280]]])
# tensor([[[-0.1414]],
#
#         [[ 0.1442]],
#
#         [[ 0.2734]],
#
#         [[-0.6687]]])
# tensor([[[ 0.0141]],
#
#         [[ 0.1442]],
#
#         [[ 1.6520]],
#
#         [[-0.6860]]])
# tensor([[[-0.2932]],
#
#         [[ 0.1442]],
#
#         [[ 0.1147]],
#
#         [[-0.3321]]])
# tensor([[[-0.6388]],
#
#         [[ 0.1442]],
#
#         [[-1.7591]],
#
#         [[-0.7289]]])
# tensor([[[-0.3316]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4058]]])
# tensor([[[-0.2336]],
#
#         [[ 0.1442]],
#
#         [[-1.0508]],
#
#         [[-0.5878]]])
# tensor([[[-0.8574]],
#
#         [[ 0.1442]],
#
#         [[-1.0176]],
#
#         [[ 1.7721]]])
# tensor([[[-0.7988]],
#
#         [[ 0.1442]],
#
#         [[-0.5865]],
#
#         [[-0.6432]]])
# tensor([[[-0.5629]],
#
#         [[ 0.1442]],
#
#         [[ 1.2304]],
#
#         [[-0.7195]]])
# tensor([[[-0.9526]],
#
#         [[ 0.1442]],
#
#         [[-0.8187]],
#
#         [[ 1.9981]]])
# tensor([[[-0.5721]],
#
#         [[ 0.1442]],
#
#         [[-1.0461]],
#
#         [[-0.1669]]])
# tensor([[[ 0.0474]],
#
#         [[ 0.1442]],
#
#         [[ 0.1123]],
#
#         [[-0.3878]]])
# tensor([[[ 0.1912]],
#
#         [[ 0.1442]],
#
#         [[-1.0532]],
#
#         [[-0.5892]]])
# tensor([[[-0.7648]],
#
#         [[ 0.1442]],
#
#         [[-0.1625]],
#
#         [[-0.6877]]])
# tensor([[[-0.7561]],
#
#         [[ 0.1442]],
#
#         [[-1.0532]],
#
#         [[-0.4367]]])
# tensor([[[-1.0301]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4586]]])
# tensor([[[-1.0642]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.6245]]])
# tensor([[[ 0.1868]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9247]]])
# tensor([[[-0.5062]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.4126]]])
# tensor([[[0.0555]],
#
#         [[0.1442]],
#
#         [[0.8135]],
#
#         [[2.0052]]])
# tensor([[[-0.3676]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[ 0.7157]]])
# tensor([[[-0.8525]],
#
#         [[ 0.1442]],
#
#         [[-1.0627]],
#
#         [[-0.6692]]])
# tensor([[[-0.2123]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.5927]]])
# tensor([[[-0.6199]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6739]]])
# tensor([[[-0.6464]],
#
#         [[ 0.1442]],
#
#         [[-0.1743]],
#
#         [[ 0.0082]]])
# tensor([[[-0.2109]],
#
#         [[ 0.1442]],
#
#         [[ 0.8135]],
#
#         [[ 2.0052]]])
# tensor([[[-0.9018]],
#
#         [[ 0.1442]],
#
#         [[-0.3165]],
#
#         [[-0.3596]]])
# tensor([[[ 0.0129]],
#
#         [[ 0.1442]],
#
#         [[ 0.8111]],
#
#         [[-0.7074]]])
# tensor([[[-0.0586]],
#
#         [[ 0.1442]],
#
#         [[-1.3848]],
#
#         [[ 0.3382]]])
# tensor([[[-1.0139]],
#
#         [[ 0.1442]],
#
#         [[ 1.1072]],
#
#         [[-0.2926]]])
# tensor([[[-0.1805]],
#
#         [[ 0.1442]],
#
#         [[-0.9608]],
#
#         [[-0.7276]]])
# tensor([[[-0.9194]],
#
#         [[ 0.1442]],
#
#         [[ 0.2449]],
#
#         [[-0.6740]]])
# tensor([[[-0.3015]],
#
#         [[ 0.1442]],
#
#         [[-1.0342]],
#
#         [[-0.5331]]])
# tensor([[[-1.0749]],
#
#         [[ 0.1442]],
#
#         [[ 1.4317]],
#
#         [[ 1.5870]]])
# tensor([[[-0.6794]],
#
#         [[ 0.1442]],
#
#         [[-1.0271]],
#
#         [[ 1.5731]]])
# tensor([[[-1.0992]],
#
#         [[ 0.1442]],
#
#         [[-1.0532]],
#
#         [[-0.5167]]])
# tensor([[[-0.6611]],
#
#         [[ 0.1442]],
#
#         [[-0.8092]],
#
#         [[ 1.9797]]])
# tensor([[[ 0.1857]],
#
#         [[ 0.1442]],
#
#         [[-1.0508]],
#
#         [[ 1.5812]]])
# tensor([[[-0.5717]],
#
#         [[ 0.1442]],
#
#         [[-1.0579]],
#
#         [[-0.3896]]])
# tensor([[[-0.5458]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.5842]]])
# tensor([[[-1.0670]],
#
#         [[ 0.1442]],
#
#         [[ 0.7566]],
#
#         [[-0.7026]]])
# tensor([[[-0.8828]],
#
#         [[ 0.1442]],
#
#         [[-1.0366]],
#
#         [[-0.1153]]])
# tensor([[[-0.5670]],
#
#         [[ 0.1442]],
#
#         [[ 2.9573]],
#
#         [[-0.6964]]])
# tensor([[[-0.9243]],
#
#         [[ 0.1442]],
#
#         [[ 1.2304]],
#
#         [[-0.7289]]])
# tensor([[[-0.5206]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.6245]]])
# tensor([[[-0.7451]],
#
#         [[ 0.1442]],
#
#         [[-1.0058]],
#
#         [[-0.7289]]])
# tensor([[[-0.4381]],
#
#         [[ 0.1442]],
#
#         [[-0.1507]],
#
#         [[-0.3510]]])
# tensor([[[ 0.1757]],
#
#         [[ 0.1442]],
#
#         [[ 1.6662]],
#
#         [[-0.7096]]])
# tensor([[[-0.3308]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.6485]]])
# tensor([[[-0.4268]],
#
#         [[ 0.1442]],
#
#         [[ 0.3207]],
#
#         [[-0.7276]]])
# tensor([[[-0.5696]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.6378]]])
# tensor([[[-0.3612]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.1875]]])
# tensor([[[-0.2330]],
#
#         [[ 0.1442]],
#
#         [[ 0.2449]],
#
#         [[-0.6740]]])
# tensor([[[ 0.0381]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.0347]]])
# tensor([[[ 0.1744]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.2304]]])
# tensor([[[-0.5972]],
#
#         [[ 0.1442]],
#
#         [[-1.0224]],
#
#         [[-0.4435]]])
# tensor([[[-1.0685]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.5927]]])
# tensor([[[ 0.1336]],
#
#         [[ 0.1442]],
#
#         [[ 1.2304]],
#
#         [[-0.7289]]])
# tensor([[[-0.1011]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.0002]]])
# tensor([[[ 0.1897]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.0350]]])
# tensor([[[-0.8838]],
#
#         [[ 0.1442]],
#
#         [[ 0.2686]],
#
#         [[-0.6840]]])
# tensor([[[-0.3887]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.9247]]])
# tensor([[[-0.4348]],
#
#         [[ 0.1442]],
#
#         [[ 0.8135]],
#
#         [[ 2.0052]]])
# tensor([[[-0.5462]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.0348]]])
# tensor([[[-0.2874]],
#
#         [[ 0.1442]],
#
#         [[ 0.8135]],
#
#         [[ 2.0052]]])
# tensor([[[-0.1754]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.2304]]])
# tensor([[[-0.4179]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.7746]]])
# tensor([[[-0.3239]],
#
#         [[ 0.1442]],
#
#         [[ 0.1573]],
#
#         [[ 1.6225]]])
# tensor([[[0.1152]],
#
#         [[0.1442]],
#
#         [[0.8135]],
#
#         [[2.0052]]])
# tensor([[[-0.6378]],
#
#         [[ 0.1442]],
#
#         [[-1.0153]],
#
#         [[-0.1007]]])
# tensor([[[ 0.0845]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.5926]]])
# tensor([[[-1.0492]],
#
#         [[ 0.1442]],
#
#         [[-0.9608]],
#
#         [[-0.7276]]])
# tensor([[[-0.1291]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.2840]]])
# tensor([[[-1.0701]],
#
#         [[ 0.1442]],
#
#         [[-1.0295]],
#
#         [[ 1.9515]]])
# tensor([[[-0.0919]],
#
#         [[ 0.1442]],
#
#         [[ 0.0981]],
#
#         [[-0.3161]]])
# tensor([[[-0.1134]],
#
#         [[ 0.1442]],
#
#         [[-1.0058]],
#
#         [[-0.7289]]])
# tensor([[[-0.4662]],
#
#         [[ 0.1442]],
#
#         [[ 0.2663]],
#
#         [[-0.6996]]])
# tensor([[[-0.7501]],
#
#         [[ 0.1442]],
#
#         [[-1.7449]],
#
#         [[-0.6886]]])
# tensor([[[-1.1007]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[ 1.9998]]])
# tensor([[[-0.6845]],
#
#         [[ 0.1442]],
#
#         [[-0.0962]],
#
#         [[-0.5145]]])
# tensor([[[-0.2870]],
#
#         [[ 0.1442]],
#
#         [[ 1.0527]],
#
#         [[-0.2847]]])
# tensor([[[ 0.1242]],
#
#         [[ 0.1442]],
#
#         [[-1.0911]],
#
#         [[ 1.5708]]])
# tensor([[[-0.4210]],
#
#         [[ 0.1442]],
#
#         [[ 0.0933]],
#
#         [[-0.3269]]])
# tensor([[[-0.4514]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.7746]]])
# tensor([[[-0.6659]],
#
#         [[ 0.1442]],
#
#         [[ 0.1644]],
#
#         [[ 1.6408]]])
# tensor([[[-0.1673]],
#
#         [[ 0.1442]],
#
#         [[-0.8187]],
#
#         [[ 1.9982]]])
# tensor([[[-0.7181]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4380]]])
# tensor([[[-0.9952]],
#
#         [[ 0.1442]],
#
#         [[-1.0319]],
#
#         [[-0.5093]]])
# tensor([[[ 0.0554]],
#
#         [[ 0.1442]],
#
#         [[ 0.2449]],
#
#         [[-0.6740]]])
# tensor([[[-0.2070]],
#
#         [[ 0.1442]],
#
#         [[ 0.2568]],
#
#         [[-0.6399]]])
# tensor([[[ 0.1358]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.4126]]])
# tensor([[[-1.0578]],
#
#         [[ 0.1442]],
#
#         [[ 0.8111]],
#
#         [[-0.5547]]])
# tensor([[[-0.7151]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.3429]]])
# tensor([[[-0.1369]],
#
#         [[ 0.1442]],
#
#         [[ 1.4317]],
#
#         [[ 1.5870]]])
# tensor([[[-0.0145]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6740]]])
# tensor([[[-1.0674]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.5927]]])
# tensor([[[-0.7461]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[ 0.7177]]])
# tensor([[[-1.0226]],
#
#         [[ 0.1442]],
#
#         [[-1.0461]],
#
#         [[-0.4161]]])
# tensor([[[-1.1147]],
#
#         [[ 0.1442]],
#
#         [[-0.9608]],
#
#         [[-0.7276]]])
# tensor([[[-1.1421]],
#
#         [[ 0.1442]],
#
#         [[-1.0295]],
#
#         [[-0.4473]]])
# tensor([[[-1.1101]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.6781]]])
# tensor([[[-0.3468]],
#
#         [[ 0.1442]],
#
#         [[ 1.4317]],
#
#         [[ 1.5909]]])
# tensor([[[-0.8217]],
#
#         [[ 0.1442]],
#
#         [[-1.0650]],
#
#         [[ 1.5319]]])
# tensor([[[-0.0663]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.7129]]])
# tensor([[[-0.2057]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.7317]]])
# tensor([[[-0.8033]],
#
#         [[ 0.1442]],
#
#         [[-1.7591]],
#
#         [[-0.7289]]])
# tensor([[[-0.2619]],
#
#         [[ 0.1442]],
#
#         [[-1.0058]],
#
#         [[-0.5574]]])
# tensor([[[-0.5193]],
#
#         [[ 0.1442]],
#
#         [[ 0.2189]],
#
#         [[-0.6975]]])
# tensor([[[-0.8728]],
#
#         [[ 0.1442]],
#
#         [[-1.0698]],
#
#         [[ 1.6092]]])
# tensor([[[-0.4223]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.7746]]])
# tensor([[[0.1048]],
#
#         [[0.1442]],
#
#         [[0.1526]],
#
#         [[0.7156]]])
# tensor([[[ 0.0467]],
#
#         [[ 0.1442]],
#
#         [[-1.0603]],
#
#         [[ 1.4962]]])
# tensor([[[-0.4119]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.5280]]])
# tensor([[[-0.3148]],
#
#         [[ 0.1442]],
#
#         [[-0.0962]],
#
#         [[-0.5145]]])
# tensor([[[-0.5694]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.6245]]])
# tensor([[[0.0750]],
#
#         [[0.1442]],
#
#         [[1.4317]],
#
#         [[1.5909]]])
# tensor([[[-0.3548]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[ 0.7158]]])
# tensor([[[-1.0676]],
#
#         [[ 0.1442]],
#
#         [[-1.0319]],
#
#         [[ 1.6446]]])
# tensor([[[-0.5670]],
#
#         [[ 0.1442]],
#
#         [[-1.0390]],
#
#         [[ 1.6479]]])
# tensor([[[ 0.1634]],
#
#         [[ 0.1442]],
#
#         [[ 0.1004]],
#
#         [[-0.3599]]])
# tensor([[[-0.4017]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.6592]]])
# tensor([[[ 0.0704]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6739]]])
# tensor([[[-0.2782]],
#
#         [[ 0.1442]],
#
#         [[-0.2028]],
#
#         [[-0.0059]]])
# tensor([[[-1.0148]],
#
#         [[ 0.1442]],
#
#         [[ 0.8229]],
#
#         [[ 2.0142]]])
# tensor([[[-0.5945]],
#
#         [[ 0.1442]],
#
#         [[ 1.4317]],
#
#         [[ 1.5908]]])
# tensor([[[-0.5502]],
#
#         [[ 0.1442]],
#
#         [[-1.0200]],
#
#         [[ 1.9846]]])
# tensor([[[ 0.0466]],
#
#         [[ 0.1442]],
#
#         [[ 1.0811]],
#
#         [[-0.2877]]])
# tensor([[[-0.4026]],
#
#         [[ 0.1442]],
#
#         [[ 0.3207]],
#
#         [[-0.7276]]])
# tensor([[[-0.0066]],
#
#         [[ 0.1442]],
#
#         [[-0.8187]],
#
#         [[ 1.9981]]])
# tensor([[[-1.0951]],
#
#         [[ 0.1442]],
#
#         [[ 0.7756]],
#
#         [[-0.7289]]])
# tensor([[[-0.4187]],
#
#         [[ 0.1442]],
#
#         [[ 1.6520]],
#
#         [[-0.6860]]])
# tensor([[[-0.1406]],
#
#         [[ 0.1442]],
#
#         [[ 0.3207]],
#
#         [[-0.7276]]])
# tensor([[[-0.8381]],
#
#         [[ 0.1442]],
#
#         [[-1.0532]],
#
#         [[-0.1923]]])
# tensor([[[-1.1126]],
#
#         [[ 0.1442]],
#
#         [[-0.3354]],
#
#         [[-0.4447]]])
# tensor([[[-1.0265]],
#
#         [[ 0.1442]],
#
#         [[ 0.1478]],
#
#         [[ 0.6964]]])
# tensor([[[-0.5150]],
#
#         [[ 0.1442]],
#
#         [[ 0.2497]],
#
#         [[-0.6440]]])
# tensor([[[-0.3750]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.3429]]])
# tensor([[[-0.6036]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8282]]])
# tensor([[[-0.6424]],
#
#         [[ 0.1442]],
#
#         [[-0.5842]],
#
#         [[-0.6454]]])
# tensor([[[ 0.0966]],
#
#         [[ 0.1442]],
#
#         [[-1.0295]],
#
#         [[-0.4187]]])
# tensor([[[-0.5409]],
#
# ...
#
#         [[ 0.1442]],
#
#         [[-1.0224]],
#
#         [[ 1.7203]]])
# tensor([[[-0.4777]],
#
#         [[ 0.1442]],
#
#         [[-1.4085]],
#
#         [[ 0.6250]]])
# tensor([[[-0.0078]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.3433]]])
# tensor([[[-0.2152]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.3307]]])
# tensor([[[-0.7507]],
#
#         [[ 0.1442]],
#
#         [[ 0.7969]],
#
#         [[ 2.0140]]])
# tensor([[[-0.6202]],
#
#         [[ 0.1442]],
#
#         [[-1.0271]],
#
#         [[ 1.4389]]])
# tensor([[[ 0.1605]],
#
#         [[ 0.1442]],
#
#         [[-1.3896]],
#
#         [[ 0.2974]]])
# tensor([[[-1.0211]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.6781]]])
# tensor([[[-1.1195]],
#
#         [[ 0.1442]],
#
#         [[-1.3327]],
#
#         [[ 0.6214]]])
# tensor([[[-0.4072]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.0180]]])
# tensor([[[-0.5327]],
#
#         [[ 0.1442]],
#
#         [[-0.1601]],
#
#         [[-0.0125]]])
# tensor([[[-0.6376]],
#
#         [[ 0.1442]],
#
#         [[ 0.1620]],
#
#         [[ 1.6191]]])
# tensor([[[-1.0467]],
#
#         [[ 0.1442]],
#
#         [[ 1.6473]],
#
#         [[-0.7289]]])
# tensor([[[ 0.1230]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.5923]]])
# tensor([[[-0.5891]],
#
#         [[ 0.1442]],
#
#         [[-1.0579]],
#
#         [[ 1.7732]]])
# tensor([[[ 0.0255]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[ 0.0002]]])
# tensor([[[-0.5934]],
#
#         [[ 0.1442]],
#
#         [[ 1.4317]],
#
#         [[ 1.5870]]])
# tensor([[[-1.0078]],
#
#         [[ 0.1442]],
#
#         [[ 0.3207]],
#
#         [[-0.7276]]])
# tensor([[[-0.9548]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.4905]]])
# tensor([[[-0.0897]],
#
#         [[ 0.1442]],
#
#         [[ 1.6520]],
#
#         [[-0.6860]]])
# tensor([[[-0.2081]],
#
#         [[ 0.1442]],
#
#         [[-1.3682]],
#
#         [[ 0.5839]]])
# tensor([[[ 0.0128]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.3429]]])
# tensor([[[-0.4305]],
#
#         [[ 0.1442]],
#
#         [[-1.3896]],
#
#         [[ 0.6593]]])
# tensor([[[-0.7996]],
#
#         [[ 0.1442]],
#
#         [[-0.9347]],
#
#         [[-0.7226]]])
# tensor([[[-0.9901]],
#
#         [[ 0.1442]],
#
#         [[ 0.1644]],
#
#         [[ 1.6462]]])
# tensor([[[-0.3417]],
#
#         [[ 0.1442]],
#
#         [[-0.0962]],
#
#         [[-0.5145]]])
# tensor([[[-0.5773]],
#
#         [[ 0.1442]],
#
#         [[ 3.0449]],
#
#         [[-0.6915]]])
# tensor([[[-0.3131]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8711]]])
# tensor([[[0.1560]],
#
#         [[0.1442]],
#
#         [[0.1455]],
#
#         [[1.6433]]])
# tensor([[[ 0.1925]],
#
#         [[ 0.1442]],
#
#         [[ 1.6473]],
#
#         [[-0.7289]]])
# tensor([[[-0.7990]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.5735]]])
# tensor([[[-0.2622]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.3629]]])
# tensor([[[-0.4327]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6738]]])
# tensor([[[-0.6486]],
#
#         [[ 0.1442]],
#
#         [[-0.1909]],
#
#         [[-0.3303]]])
# tensor([[[-1.0366]],
#
#         [[ 0.1442]],
#
#         [[ 0.7613]],
#
#         [[-0.6973]]])
# tensor([[[-1.1284]],
#
#         [[ 0.1442]],
#
#         [[-1.0011]],
#
#         [[-0.4644]]])
# tensor([[[ 0.0209]],
#
#         [[ 0.1442]],
#
#         [[-1.0603]],
#
#         [[-0.5128]]])
# tensor([[[ 0.0376]],
#
#         [[ 0.1442]],
#
#         [[-1.0461]],
#
#         [[ 1.7795]]])
# tensor([[[-0.7499]],
#
#         [[ 0.1442]],
#
#         [[ 0.1644]],
#
#         [[ 0.6936]]])
# tensor([[[-0.8289]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.5280]]])
# tensor([[[-1.0312]],
#
#         [[ 0.1442]],
#
#         [[-1.0342]],
#
#         [[-0.2088]]])
# tensor([[[-0.8817]],
#
#         [[ 0.1442]],
#
#         [[-0.3283]],
#
#         [[-0.4103]]])
# tensor([[[-0.1979]],
#
#         [[ 0.1442]],
#
#         [[ 1.0811]],
#
#         [[-0.2877]]])
# tensor([[[-0.6059]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.3590]]])
# tensor([[[-0.4835]],
#
#         [[ 0.1442]],
#
#         [[-0.3070]],
#
#         [[-0.4095]]])
# tensor([[[-0.8701]],
#
#         [[ 0.1442]],
#
#         [[ 0.3207]],
#
#         [[-0.7276]]])
# tensor([[[-0.8285]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.3429]]])
# tensor([[[-0.0124]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.0351]]])
# tensor([[[-1.1442]],
#
#         [[ 0.1442]],
#
#         [[-1.0650]],
#
#         [[ 1.7359]]])
# tensor([[[-0.6437]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.2145]]])
# tensor([[[-0.5817]],
#
#         [[ 0.1442]],
#
#         [[-1.0603]],
#
#         [[-0.3265]]])
# tensor([[[-0.1153]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[-0.5927]]])
# tensor([[[-0.4356]],
#
#         [[ 0.1442]],
#
#         [[-1.0271]],
#
#         [[ 1.5983]]])
# tensor([[[ 0.1899]],
#
#         [[ 0.1442]],
#
#         [[-1.0532]],
#
#         [[ 1.5922]]])
# tensor([[[-0.1842]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8282]]])
# tensor([[[-0.4268]],
#
#         [[ 0.1442]],
#
#         [[ 0.3042]],
#
#         [[-0.6893]]])
# tensor([[[-0.2825]],
#
#         [[ 0.1442]],
#
#         [[-1.7591]],
#
#         [[-0.7289]]])
# tensor([[[-0.1222]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.3429]]])
# tensor([[[-0.2984]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.5280]]])
# tensor([[[-0.3089]],
#
#         [[ 0.1442]],
#
#         [[-0.0962]],
#
#         [[-0.5145]]])
# tensor([[[-0.4111]],
#
#         [[ 0.1442]],
#
#         [[ 2.9715]],
#
#         [[-0.6915]]])
# tensor([[[-0.9372]],
#
#         [[ 0.1442]],
#
#         [[-1.0224]],
#
#         [[-0.5955]]])
# tensor([[[-0.9248]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8711]]])
# tensor([[[-0.2344]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4487]]])
# tensor([[[ 0.1126]],
#
#         [[ 0.1442]],
#
#         [[-1.3848]],
#
#         [[ 0.2309]]])
# tensor([[[-0.2118]],
#
#         [[ 0.1442]],
#
#         [[ 0.8135]],
#
#         [[ 2.0052]]])
# tensor([[[-0.2437]],
#
#         [[ 0.1442]],
#
#         [[-1.3682]],
#
#         [[ 0.6269]]])
# tensor([[[-1.1100]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4702]]])
# tensor([[[-0.9765]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.5816]]])
# tensor([[[ 0.1757]],
#
#         [[ 0.1442]],
#
#         [[-1.3824]],
#
#         [[ 0.6814]]])
# tensor([[[-1.0214]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[ 1.6522]]])
# tensor([[[-0.3526]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.6245]]])
# tensor([[[ 0.1675]],
#
#         [[ 0.1442]],
#
#         [[-1.0792]],
#
#         [[ 2.0055]]])
# tensor([[[-0.9019]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.8711]]])
# tensor([[[-0.3176]],
#
#         [[ 0.1442]],
#
#         [[-1.0461]],
#
#         [[-0.6169]]])
# tensor([[[-0.9633]],
#
#         [[ 0.1442]],
#
#         [[ 1.1048]],
#
#         [[-0.2887]]])
# tensor([[[-0.5999]],
#
#         [[ 0.1442]],
#
#         [[-0.8281]],
#
#         [[ 1.9815]]])
# tensor([[[-1.0236]],
#
#         [[ 0.1442]],
#
#         [[ 3.0236]],
#
#         [[-0.6963]]])
# tensor([[[-0.6357]],
#
#         [[ 0.1442]],
#
#         [[-0.1862]],
#
#         [[ 0.3411]]])
# tensor([[[0.1355]],
#
#         [[0.1442]],
#
#         [[0.1786]],
#
#         [[1.6301]]])
# tensor([[[-0.3414]],
#
#         [[ 0.1442]],
#
#         [[-0.1720]],
#
#         [[-0.6860]]])
# tensor([[[-1.1353]],
#
#         [[ 0.1442]],
#
#         [[-1.0840]],
#
#         [[-0.6484]]])
# tensor([[[-0.1992]],
#
#         [[ 0.1442]],
#
#         [[-1.0271]],
#
#         [[ 1.6031]]])
# tensor([[[-0.1644]],
#
#         [[ 0.1442]],
#
#         [[ 1.0811]],
#
#         [[-0.2877]]])
# tensor([[[ 0.0057]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.3308]]])
# tensor([[[ 0.1906]],
#
#         [[ 0.1442]],
#
#         [[-0.1886]],
#
#         [[-0.0084]]])
# tensor([[[-0.3440]],
#
#         [[ 0.1442]],
#
#         [[-1.0603]],
#
#         [[-0.3391]]])
# tensor([[[-0.3165]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.2625]]])
# tensor([[[ 0.0993]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[-0.2304]]])
# tensor([[[-0.3101]],
#
#         [[ 0.1442]],
#
#         [[-1.3824]],
#
#         [[ 0.6063]]])
# tensor([[[-0.2169]],
#
#         [[ 0.1442]],
#
#         [[-1.0437]],
#
#         [[-0.5199]]])
# tensor([[[-0.7411]],
#
#         [[ 0.1442]],
#
#         [[ 3.0236]],
#
#         [[-0.2081]]])
# tensor([[[-0.5051]],
#
#         [[ 0.1442]],
#
#         [[ 1.2304]],
#
#         [[-0.7289]]])
# tensor([[[-0.1122]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.6781]]])
# tensor([[[-0.4860]],
#
#         [[ 0.1442]],
#
#         [[-0.1554]],
#
#         [[-0.3315]]])
# tensor([[[-1.1374]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.3308]]])
# tensor([[[-0.7409]],
#
#         [[ 0.1442]],
#
#         [[-1.3801]],
#
#         [[ 0.3317]]])
# tensor([[[-0.8768]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.4851]]])
# tensor([[[-0.6799]],
#
#         [[ 0.1442]],
#
#         [[-0.3354]],
#
#         [[-0.3998]]])
# tensor([[[-0.8698]],
#
#         [[ 0.1442]],
#
#         [[-1.3564]],
#
#         [[ 0.2664]]])
# tensor([[[-0.2237]],
#
#         [[ 0.1442]],
#
#         [[-1.0058]],
#
#         [[-0.5574]]])
# tensor([[[-0.1077]],
#
#         [[ 0.1442]],
#
#         [[-0.3236]],
#
#         [[-0.4381]]])
# tensor([[[ 0.1455]],
#
#         [[ 0.1442]],
#
#         [[-0.9608]],
#
#         [[-0.7276]]])
# tensor([[[ 0.0443]],
#
#         [[ 0.1442]],
#
#         [[-0.1838]],
#
#         [[-0.3266]]])
# tensor([[[-0.3732]],
#
#         [[ 0.1442]],
#
#         [[-0.0962]],
#
#         [[-0.5145]]])
# tensor([[[ 0.1868]],
#
#         [[ 0.1442]],
#
#         [[-0.1696]],
#
#         [[ 0.3388]]])
# tensor([[[-0.9390]],
#
#         [[ 0.1442]],
#
#         [[-0.3307]],
#
#         [[-0.3894]]])
# tensor([[[-0.1753]],
#
#         [[ 0.1442]],
#
#         [[-1.3824]],
#
#         [[ 0.6278]]])
# tensor([[[ 0.1062]],
#
#         [[ 0.1442]],
#
#         [[-1.0248]],
#
#         [[-0.2069]]])
# tensor([[[-0.1528]],
#
#         [[ 0.1442]],
#
#         [[ 0.1526]],
#
#         [[ 0.7158]]])
# tensor([[[-0.7508]],
#
#         [[ 0.1442]],
#
#         [[-0.5865]],
#
#         [[-0.6432]]])
# tensor([[[-0.9651]],
#
#         [[ 0.1442]],
#
#         [[-1.0295]],
#
#         [[-0.1189]]])
# tensor([[[-0.2804]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.7317]]])
# tensor([[[-1.1156]],
#
#         [[ 0.1442]],
#
#         [[-1.3730]],
#
#         [[ 0.2575]]])
# tensor([[[ 0.1554]],
#
#         [[ 0.1442]],
#
#         [[-1.0342]],
#
#         [[-0.5664]]])
# tensor([[[-0.6285]],
#
#         [[ 0.1442]],
#
#         [[ 0.2686]],
#
#         [[-0.6774]]])
# tensor([[[-1.1325]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.6739]]])
# tensor([[[-0.8214]],
#
#         [[ 0.1442]],
#
#         [[-0.0772]],
#
#         [[-0.5183]]])
# tensor([[[-0.0065]],
#
#         [[ 0.1442]],
#
#         [[-0.8187]],
#
#         [[ 1.9981]]])
# tensor([[[-0.6123]],
#
#         [[ 0.1442]],
#
#         [[ 0.7756]],
#
#         [[-0.7289]]])
# tensor([[[-0.1263]],
#
#         [[ 0.1442]],
#
#         [[ 0.8087]],
#
#         [[ 2.0107]]])
# tensor([[[ 0.0439]],
#
#         [[ 0.1442]],
#
#         [[ 0.2805]],
#
#         [[-0.7109]]])
# tensor([[[-0.2346]],
#
#         [[ 0.1442]],
#
#         [[ 1.0811]],
#
#         [[-0.2877]]])
# tensor([[[-0.4425]],
#
#         [[ 0.1442]],
#
#         [[ 0.1075]],
#
#         [[-0.3308]]])
# tensor([[[ 0.0849]],
#
#         [[ 0.1442]],
#
#         [[ 0.1549]],
#
#         [[-0.7052]]])
# tensor([[[-0.4647]],
#
#         [[ 0.1442]],
#
#         [[-1.0508]],
#
#         [[ 1.6670]]])
# tensor([[[-0.8202]],
#
#         [[ 0.1442]],
#
#         [[-1.3919]],
#
#         [[ 0.3844]]])
# tensor([[[-0.5901]],
#
#         [[ 0.1442]],
#
#         [[-0.1554]],
#
#         [[-0.0096]]])
# tensor([[[-1.1131]],
#
#         [[ 0.1442]],
#
#         [[ 1.6473]],
#
#         [[-0.7289]]])
# tensor([[[-0.0697]],
#
#         [[ 0.1442]],
#
#         [[-1.0461]],
#
#         [[ 1.6866]]])
# tensor([[[-0.7586]],
#
#         [[ 0.1442]],
#
#         [[-1.0342]],
#
#         [[-0.2790]]])
# tensor([[[-0.4265]],
#
#         [[ 0.1442]],
#
#         [[-1.0011]],
#
#         [[-0.1641]]])
# tensor([[[-0.7279]],
#
#         [[ 0.1442]],
#
#         [[-1.0058]],
#
#         [[-0.5574]]])
# tensor([[[-0.4649]],
#
#         [[ 0.1442]],
#
#         [[-1.0413]],
#
#         [[ 1.7746]]])
# tensor([[[-1.0234]],
#
#         [[ 0.1442]],
#
#         [[-1.0579]],
#
#         [[-0.2732]]])
# tensor([[[0.1446]],
#
#         [[0.1442]],
#
#         [[0.8135]],
#
#         [[2.0052]]])
# tensor([[[ 0.0329]],
#
#         [[ 0.1442]],
#
#         [[ 1.2067]],
#
#         [[-0.7212]]])
# tensor([[[-0.4790]],
#
#         [[ 0.1442]],
#
#         [[-0.9608]],
#
#         [[-0.7276]]])
# tensor([[[-0.7711]],
#
#         [[ 0.1442]],
#
#         [[-0.3094]],
#
#         [[-0.3785]]])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-aeab1c085cfa> in <module>
#       4                                  root_dir='/content/car_hacking_data')
#       5
# ----> 6 for data, target in test_loader:
#       7   #print(f"OG Data: {data.reshape(-1, 1, 1)}, Target: {target}")
#       8   print(data.reshape(-1, 1, 1))
#
# <ipython-input-2-7219d0c158c3> in __getitem__(self, idx)
#      58
#      59         features = ['Timestamp', 'DLC', 'CAN_ID', 'Data']
# ---> 60         X_train = self.validation_frame.loc[:, features].values
#      61         X_train = torch.as_tensor(X_train, dtype=torch.float32)
#      62         y = self.validation_frame['Flag'].iloc[idx]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1067             return self._multi_take(tup)
#    1068
# -> 1069         return self._getitem_tuple_same_dim(tup)
#    1070
#    1071     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     773                 continue
#     774
# --> 775             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     776             # We should never have retval.ndim < self.ndim, as that should
#     777             #  be handled by the _getitem_lowerdim call above.
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1051
#    1052         # A collection of keys
# -> 1053         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054         return self.obj._reindex_with_indexers(
#    1055             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1260         if ax._index_as_unique:
#    1261             indexer = ax.get_indexer_for(keyarr)
# -> 1262             keyarr = ax.reindex(keyarr)[0]
#    1263         else:
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    3501             target = self[:0]
#    3502         else:
# -> 3503             target = ensure_index(target)
#    3504
#    3505         if level is not None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5915             index_like = copy_func(index_like)
#    5916
# -> 5917     return Index(index_like)
#    5918
#    5919
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     252     ) -> "Index":
#     253
# --> 254         from pandas.core.indexes.range import RangeIndex
#     255
#     256         name = maybe_extract_name(name, data, cls)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %%
print(test_loader.__len__())
# Out:
# 7850

# %%
for batch_idx, (data, target) in enumerate(federated_train_loader):
  #data = data.view(args['batch_size'], 1, 1)
  print(f"Data shape: {data.shape}, Target shape: {target.shape}")

# %%
"""for (data, target) in test_loader:
  print(f"Data: {data}, Target: {target}")
"""

for data in test_loader:
  print(data)

"""v1 = ValidationDataset(csv_file='/content/car_hacking_data/clean_scaled_normal_run.csv', root_dir='/content/car_hacking_data')
print(v1.__getitem__(5))"""
# Out:
# tensor([-1.7320,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7320e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7320,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7320,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -1.0868, -0.6629], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -1.0841, -0.6946], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7320,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7320,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7320,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7320, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7320,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7320,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7320,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7320e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7320,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7320,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7320,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7320,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -1.0868, -0.6312], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -1.0841, -0.5995], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7319, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7319, -6.5372,  2.2171, -0.6999], dtype=torch.float64)
# tensor([-1.7319e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7319,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -0.0869, -0.3618], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -1.0868, -0.6418], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -1.0841,  1.9572], dtype=torch.float64)
# tensor([-1.7319,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  1.7525,  1.5858], dtype=torch.float64)
# tensor([-1.7319, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7319,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7318e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7318,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7318,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7318,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7318,  0.2429, -1.0868, -0.6841], dtype=torch.float64)
# tensor([-1.7318,  0.2429, -1.0841,  1.8621], dtype=torch.float64)
# tensor([-1.7318,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7318,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7318,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7318,  0.2429, -0.0869, -0.0237], dtype=torch.float64)
# tensor([-1.7318,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7318,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7318,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7318,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7318, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7318,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7318,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7318,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7318e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7318,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7318,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7318,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7318,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -1.0868,  1.9783], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -1.0841,  1.8198], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7317, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7317e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7317,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  1.9998, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  2.0052, -0.6576], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -1.0868,  1.9572], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -1.0841,  1.9572], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7317,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7317, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7317,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7316e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7316,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7316,  0.2429,  2.6519, -0.6999], dtype=torch.float64)
# tensor([-1.7316,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7316,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7316,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7316,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7316,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7316,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7316,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7316,  0.2429, -0.0869, -0.3618], dtype=torch.float64)
# tensor([-1.7316,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7316,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7316,  0.2429, -1.0868,  1.9994], dtype=torch.float64)
# tensor([-1.7316,  0.2429, -1.0841, -0.5467], dtype=torch.float64)
# tensor([-1.7316,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7316,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7316, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7316,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7316,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7316,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7316, -6.5372,  2.2171, -0.6999], dtype=torch.float64)
# tensor([-1.7316e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7316,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -1.0868, -0.6841], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -1.0841, -0.5467], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -0.0869, -0.0237], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  1.7525,  1.5858], dtype=torch.float64)
# tensor([-1.7315, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -1.4781,  0.3092], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -1.4754,  0.6577], dtype=torch.float64)
# tensor([-1.7315e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7315,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -1.0868, -0.6841], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -1.0841, -0.6946], dtype=torch.float64)
# tensor([-1.7315,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7315, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7315,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7314,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7314e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7314,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7314,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7314,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7314,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7314,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7314,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7314,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7314,  0.2429, -1.0868, -0.6629], dtype=torch.float64)
# tensor([-1.7314,  0.2429, -1.0841, -0.5995], dtype=torch.float64)
# tensor([-1.7314,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7314,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# tensor([-1.7314,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7314,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7314, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7314,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7314,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7314,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7314e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7313,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -0.0869, -0.3618], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -1.0868, -0.6312], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -1.0841, -0.5995], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7313, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7313e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7313,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -1.0868, -0.6629], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -1.0841,  1.9149], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7313,  0.2429, -0.0869, -0.0237], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7313,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7313, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7312,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7312,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7312,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7312, -6.5372,  2.2171, -0.6999], dtype=torch.float64)
# tensor([-1.7312e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7312,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7312,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7312,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7312,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7312,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7312,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7312,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7312,  0.2429, -1.0868,  1.9572], dtype=torch.float64)
# tensor([-1.7312,  0.2429, -1.0841,  1.6719], dtype=torch.float64)
# tensor([-1.7312,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7312,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7312,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7312,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7312,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7312,  0.2429,  1.7525,  1.5858], dtype=torch.float64)
# tensor([-1.7312, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7312,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7312,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7312,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7311e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7311,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7311,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7311,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -1.0868,  1.9255], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -1.0841,  1.8621], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# tensor([-1.7311,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7311,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7311, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7311,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7311,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7311,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7311e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7311,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7311,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7311,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -0.0869, -0.3618], dtype=torch.float64)
# tensor([-1.7311,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7311,  0.2429,  0.2853, -0.5655], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -1.0868,  1.9360], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -1.0841, -0.6418], dtype=torch.float64)
# tensor([-1.7311,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7310,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7310, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7310,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7310,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7310,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7310e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7310,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7310,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7310,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7310,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7310,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7310,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7310,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7310,  0.2429, -1.0868,  1.9783], dtype=torch.float64)
# tensor([-1.7310,  0.2429, -1.0841, -0.5467], dtype=torch.float64)
# tensor([-1.7310,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7310,  0.2429, -0.0869, -0.0237], dtype=torch.float64)
# tensor([-1.7310,  0.2429,  0.2853, -0.5655], dtype=torch.float64)
# tensor([-1.7310,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7310, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7310,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7310,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7310,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7309e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7309,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7309,  0.2429,  2.6519, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7309,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7309,  0.2429,  0.2853, -0.5655], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -1.0868, -0.6946], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -1.0841, -0.5467], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7309, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7309,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7309,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7309, -6.5372,  2.2171, -0.6999], dtype=torch.float64)
# tensor([-1.7309e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7309,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -1.0868, -0.6735], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -1.0841, -0.5467], dtype=torch.float64)
# tensor([-1.7309,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  0.2853, -0.5655], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  1.7525,  1.5858], dtype=torch.float64)
# tensor([-1.7308, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7308,  0.2429, -1.4781,  0.3092], dtype=torch.float64)
# tensor([-1.7308,  0.2429, -1.4754,  0.6577], dtype=torch.float64)
# tensor([-1.7308e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7308,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7308,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7308,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7308,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7308,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7308,  0.2429, -1.0868, -0.6207], dtype=torch.float64)
# tensor([-1.7308,  0.2429, -1.0841, -0.5045], dtype=torch.float64)
# tensor([-1.7308,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7308,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7308,  0.2429, -0.0869, -0.3618], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  0.2853, -0.5655], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7308, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7308,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7307e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7307,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7307,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7307,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -1.0868, -0.6207], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -1.0841, -0.6946], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -0.0869, -0.0237], dtype=torch.float64)
# tensor([-1.7307,  0.2429,  0.2853, -0.5655], dtype=torch.float64)
# tensor([-1.7307,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7307, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7307,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7307,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7307,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7307e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7307,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7307,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7307,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7307,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  0.2853, -0.5655], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -1.0868, -0.6629], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -1.0841,  1.9149], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7306, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7306e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7306,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -1.0868, -0.6735], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -1.0841,  1.9572], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7306,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  0.2853, -0.5655], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7306, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7306,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7305, -6.5372,  2.2171, -0.6999], dtype=torch.float64)
# tensor([-1.7305e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7305,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7305,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7305,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7305,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7305,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7305,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7305,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7305,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7305,  0.2429, -0.0869, -0.3618], dtype=torch.float64)
# tensor([-1.7305,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7305,  0.2429,  0.2853, -0.0161], dtype=torch.float64)
# tensor([-1.7305,  0.2429, -1.0868, -0.6946], dtype=torch.float64)
# tensor([-1.7305,  0.2429, -1.0841,  1.9149], dtype=torch.float64)
# tensor([-1.7305,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7305,  0.2429,  1.7525,  1.5858], dtype=torch.float64)
# tensor([-1.7305, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7305,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7305,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7305,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7305e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7305,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7305,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7305,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7305,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -1.0868,  1.9572], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -1.0841,  1.8198], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -0.0869, -0.0237], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  0.2853, -0.0161], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7304, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7304e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7304,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -1.0868,  1.9572], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -1.0841, -0.6946], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7304,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  0.2853, -0.0161], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7304, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7304,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7303e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7303,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7303,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7303,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7303,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7303,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7303,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7303,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7303,  0.2429, -1.0868,  1.9889], dtype=torch.float64)
# tensor([-1.7303,  0.2429, -1.0841, -0.5995], dtype=torch.float64)
# tensor([-1.7303,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7303,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# tensor([-1.7303,  0.2429,  0.2853, -0.0161], dtype=torch.float64)
# tensor([-1.7303,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7303, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7303,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7303,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7303,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7303e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7303,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7303,  0.2429,  2.6519, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -1.0868, -0.6841], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -1.0841, -0.5467], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -0.0869, -0.3618], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  0.2853, -0.0161], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7302, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7302, -6.5372,  2.2171, -0.6999], dtype=torch.float64)
# tensor([-1.7302e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7302,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -1.0868, -0.6418], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -1.0841, -0.5045], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7302,  0.2429, -0.0869, -0.0237], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  0.2853, -0.0161], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  1.7525,  1.5858], dtype=torch.float64)
# tensor([-1.7302, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7302,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7301,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7301,  0.2429, -1.4781,  0.3092], dtype=torch.float64)
# tensor([-1.7301,  0.2429, -1.4754,  0.6577], dtype=torch.float64)
# tensor([-1.7301e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7301,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7301,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7301,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7301,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7301,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7301,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7301,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7301,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7301,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7301,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7301,  0.2429,  0.2853, -0.0161], dtype=torch.float64)
# tensor([-1.7301,  0.2429, -1.0868, -0.6312], dtype=torch.float64)
# tensor([-1.7301,  0.2429, -1.0841, -0.6946], dtype=torch.float64)
# tensor([-1.7301,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7301,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7301, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7301,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7301,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7301,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7301e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7300,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -1.0868, -0.6629], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -1.0841,  1.9149], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  0.2853, -0.0161], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7300, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7300e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7300,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -1.0868, -0.6946], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -1.0841,  1.8621], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7300,  0.2429, -0.0869, -0.3618], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7300,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7300, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7299,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7299,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7299,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7299e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7299,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7299,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7299,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7299,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7299,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7299,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7299,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7299,  0.2429, -1.0868,  1.9994], dtype=torch.float64)
# tensor([-1.7299,  0.2429, -1.0841,  1.9572], dtype=torch.float64)
# tensor([-1.7299,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7299,  0.2429, -0.0869, -0.0237], dtype=torch.float64)
# tensor([-1.7299,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7299,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7299, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7299,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7299,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7299,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7298, -6.5372,  2.2171, -0.6999], dtype=torch.float64)
# tensor([-1.7298e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7298,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -1.0868,  1.9889], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -1.0841,  1.9572], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  1.7525,  1.5858], dtype=torch.float64)
# tensor([-1.7298, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7298e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7298,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -1.0868,  1.9783], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -1.0841,  1.9572], dtype=torch.float64)
# tensor([-1.7298,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7298,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7297, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7297,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7297,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7297,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7297e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7297,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7297,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7297,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7297,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7297,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7297,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7297,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7297,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7297,  0.2429, -0.0869, -0.3618], dtype=torch.float64)
# tensor([-1.7297,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7297,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7297,  0.2429, -1.0868,  1.9889], dtype=torch.float64)
# tensor([-1.7297,  0.2429, -1.0841, -0.6418], dtype=torch.float64)
# tensor([-1.7297,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7297,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7297, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7297,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7297,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7297,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7296e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7296,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7296,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7296,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -1.0868,  1.9994], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -1.0841, -0.5995], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -0.0869, -0.0237], dtype=torch.float64)
# tensor([-1.7296,  0.2429,  0.2853,  0.7340], dtype=torch.float64)
# tensor([-1.7296,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7296, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7296,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7296,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7296,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7296e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7296,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7296,  0.2429,  2.6519, -0.6999], dtype=torch.float64)
# tensor([-1.7296,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7296,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7296,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7296,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# ...
# tensor([-1.7293,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7293,  0.2429, -1.0868,  1.9572], dtype=torch.float64)
# tensor([-1.7293,  0.2429, -1.0841, -0.5995], dtype=torch.float64)
# tensor([-1.7293,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7293,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7293,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7293,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7293,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7293,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7293, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7293,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7293,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7293,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7292e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7292,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7292,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7292,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7292,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7292,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7292,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7292,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# tensor([-1.7292,  0.2429, -1.0868, -0.6841], dtype=torch.float64)
# tensor([-1.7292,  0.2429, -1.0841, -0.4516], dtype=torch.float64)
# tensor([-1.7292,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7292,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7292,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7292,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7292, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7292,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7292,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7292,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7292, -6.5372,  2.2171, -0.6999], dtype=torch.float64)
# tensor([-1.7292e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7292,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7292,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7292,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7292,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -1.0868, -0.6101], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -1.0841, -0.4094], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -0.0869, -0.3618], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  1.7525,  1.5858], dtype=torch.float64)
# tensor([-1.7291, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7291e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7291,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -1.0868, -0.5467], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -1.0841, -0.4516], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7291,  0.2429, -0.0869, -0.0237], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7291, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7291,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7290e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7290,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7290,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7290,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7290,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7290,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7290,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7290,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7290,  0.2429, -1.0868, -0.5467], dtype=torch.float64)
# tensor([-1.7290,  0.2429, -1.0841, -0.6946], dtype=torch.float64)
# tensor([-1.7290,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7290,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7290,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7290,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7290,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7290,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7290, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7290,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7290,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7290,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7290e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7290,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7290,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -1.0868, -0.6101], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -1.0841,  1.7670], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  0.2853,  1.6321], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7289, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7289e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7289,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  2.6519, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -1.0868, -0.6418], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -1.0841,  1.8621], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7289,  0.2429, -0.0869, -0.3618], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  0.2853, -0.5655], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7289, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7289,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7288, -6.5372,  2.2171, -0.6999], dtype=torch.float64)
# tensor([-1.7288e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7288,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7288,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7288,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7288,  0.2429, -1.0868, -0.6207], dtype=torch.float64)
# tensor([-1.7288,  0.2429, -1.0841, -0.5995], dtype=torch.float64)
# tensor([-1.7288,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7288,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7288,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7288,  0.2429, -0.0869, -0.0237], dtype=torch.float64)
# tensor([-1.7288,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7288,  0.2429,  0.2853, -0.5655], dtype=torch.float64)
# tensor([-1.7288,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7288,  0.2429,  1.7525,  1.5858], dtype=torch.float64)
# tensor([-1.7288, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7288,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7288,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7288,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7288,  0.2429, -1.4781,  0.3092], dtype=torch.float64)
# tensor([-1.7288,  0.2429, -1.4754,  0.6577], dtype=torch.float64)
# tensor([-1.7288e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7288,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7287,  0.2429,  0.9999, -0.6999], dtype=torch.float64)
# tensor([-1.7287,  0.2429,  1.3504, -0.6999], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -0.5624, -0.6999], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -0.0869,  0.3144], dtype=torch.float64)
# tensor([-1.7287,  0.2429,  0.2337, -0.6456], dtype=torch.float64)
# tensor([-1.7287,  0.2429,  0.2853, -0.5655], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -1.0868, -0.5995], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -1.0841, -0.6418], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -1.0434, -0.6999], dtype=torch.float64)
# tensor([-1.7287,  0.2429,  1.7525,  1.5821], dtype=torch.float64)
# tensor([-1.7287, -3.1471, -0.0435, -0.6999], dtype=torch.float64)
# tensor([-1.7287,  0.2429,  1.0406, -0.6973], dtype=torch.float64)
# tensor([-1.7287,  0.2429,  0.4782, -0.6986], dtype=torch.float64)
# tensor([-1.7287,  0.2429,  1.0434,  1.9942], dtype=torch.float64)
# tensor([-1.7287e+00,  2.4294e-01,  3.8467e-08, -4.8861e-01],
#        dtype=torch.float64)
# tensor([-1.7287,  0.2429,  0.3913, -0.6454], dtype=torch.float64)
# tensor([-1.7287,  0.2429,  1.5216, -0.6999], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -1.9074, -0.6999], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -0.9917, -0.6999], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -0.8287,  1.9859], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -0.2608, -0.4132], dtype=torch.float64)
# tensor([-1.7287,  0.2429, -0.0869, -0.6999], dtype=torch.float64)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-9f902558d0fd> in <module>
#       3 """
#       4
# ----> 5 for data in test_loader:
#       6   print(data)
#       7
#
# <ipython-input-11-ddd56e02b2ac> in __getitem__(self, idx)
#      53
#      54         features = ['Timestamp', 'DLC', 'CAN_ID', 'Data']
# ---> 55         X_train = self.validation_frame.loc[:, features].values
#      56         X_train = torch.as_tensor(X_train)
#      57
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1067             return self._multi_take(tup)
#    1068
# -> 1069         return self._getitem_tuple_same_dim(tup)
#    1070
#    1071     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     773                 continue
#     774
# --> 775             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     776             # We should never have retval.ndim < self.ndim, as that should
#     777             #  be handled by the _getitem_lowerdim call above.
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1053         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054         return self.obj._reindex_with_indexers(
# -> 1055             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1056         )
#    1057
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4881                 fill_value=fill_value,
#    4882                 allow_dups=allow_dups,
# -> 4883                 copy=copy,
#    4884             )
#    4885             # If we've made a copy once, no need to make another one
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#    1306         if axis == 0:
#    1307             new_blocks = self._slice_take_blocks_ax0(
# -> 1308                 indexer, fill_value=fill_value, only_slice=only_slice
#    1309             )
#    1310         else:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice)
#    1435                             blocks.append(nb)
#    1436                     else:
# -> 1437                         nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#    1438                         blocks.append(nb)
#    1439
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1394
#    1395         new_values = algos.take_nd(
# -> 1396             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1397         )
#    1398
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1757         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#    1758     )
# -> 1759     func(arr, indexer, out, fill_value)
#    1760
#    1761     if flip_order:
#
# KeyboardInterrupt:

# %% [markdown]
# # Model Shape Information using TorchInfo

# %%
# !pip install torchinfo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.1-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.1

# %%
from torchinfo import summary
from auto_esn.esn.esn import DeepESN

model2 = DeepESN()
summary(model2, input_size=(100, 1, 1))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DeepESN                                  [100, 1]                  --
# ├─DeepESNCell: 1-1                       [100, 1000]               --
# │    └─Activation: 2-1                   [1, 500]                  --
# │    └─Activation: 2-2                   [1, 500]                  --
# │    └─Activation: 2-3                   [1, 500]                  --
# │    └─Activation: 2-4                   [1, 500]                  --
# │    └─Activation: 2-5                   [1, 500]                  --
# │    └─Activation: 2-6                   [1, 500]                  --
# │    └─Activation: 2-7                   [1, 500]                  --
# │    └─Activation: 2-8                   [1, 500]                  --
# │    └─Activation: 2-9                   [1, 500]                  --
# │    └─Activation: 2-10                  [1, 500]                  --
# │    └─Activation: 2-11                  [1, 500]                  --
# │    └─Activation: 2-12                  [1, 500]                  --
# │    └─Activation: 2-13                  [1, 500]                  --
# │    └─Activation: 2-14                  [1, 500]                  --
# │    └─Activation: 2-15                  [1, 500]                  --
# │    └─Activation: 2-16                  [1, 500]                  --
# │    └─Activation: 2-17                  [1, 500]                  --
# │    └─Activation: 2-18                  [1, 500]                  --
# │    └─Activation: 2-19                  [1, 500]                  --
# │    └─Activation: 2-20                  [1, 500]                  --
# │    └─Activation: 2-21                  [1, 500]                  --
# │    └─Activation: 2-22                  [1, 500]                  --
# │    └─Activation: 2-23                  [1, 500]                  --
# │    └─Activation: 2-24                  [1, 500]                  --
# │    └─Activation: 2-25                  [1, 500]                  --
# │    └─Activation: 2-26                  [1, 500]                  --
# │    └─Activation: 2-27                  [1, 500]                  --
# │    └─Activation: 2-28                  [1, 500]                  --
# │    └─Activation: 2-29                  [1, 500]                  --
# │    └─Activation: 2-30                  [1, 500]                  --
# │    └─Activation: 2-31                  [1, 500]                  --
# │    └─Activation: 2-32                  [1, 500]                  --
# │    └─Activation: 2-33                  [1, 500]                  --
# │    └─Activation: 2-34                  [1, 500]                  --
# │    └─Activation: 2-35                  [1, 500]                  --
# │    └─Activation: 2-36                  [1, 500]                  --
# │    └─Activation: 2-37                  [1, 500]                  --
# │    └─Activation: 2-38                  [1, 500]                  --
# │    └─Activation: 2-39                  [1, 500]                  --
# │    └─Activation: 2-40                  [1, 500]                  --
# │    └─Activation: 2-41                  [1, 500]                  --
# │    └─Activation: 2-42                  [1, 500]                  --
# │    └─Activation: 2-43                  [1, 500]                  --
# │    └─Activation: 2-44                  [1, 500]                  --
# │    └─Activation: 2-45                  [1, 500]                  --
# │    └─Activation: 2-46                  [1, 500]                  --
# │    └─Activation: 2-47                  [1, 500]                  --
# │    └─Activation: 2-48                  [1, 500]                  --
# │    └─Activation: 2-49                  [1, 500]                  --
# │    └─Activation: 2-50                  [1, 500]                  --
# │    └─Activation: 2-51                  [1, 500]                  --
# │    └─Activation: 2-52                  [1, 500]                  --
# │    └─Activation: 2-53                  [1, 500]                  --
# │    └─Activation: 2-54                  [1, 500]                  --
# │    └─Activation: 2-55                  [1, 500]                  --
# │    └─Activation: 2-56                  [1, 500]                  --
# │    └─Activation: 2-57                  [1, 500]                  --
# │    └─Activation: 2-58                  [1, 500]                  --
# │    └─Activation: 2-59                  [1, 500]                  --
# │    └─Activation: 2-60                  [1, 500]                  --
# │    └─Activation: 2-61                  [1, 500]                  --
# │    └─Activation: 2-62                  [1, 500]                  --
# │    └─Activation: 2-63                  [1, 500]                  --
# │    └─Activation: 2-64                  [1, 500]                  --
# │    └─Activation: 2-65                  [1, 500]                  --
# │    └─Activation: 2-66                  [1, 500]                  --
# │    └─Activation: 2-67                  [1, 500]                  --
# │    └─Activation: 2-68                  [1, 500]                  --
# │    └─Activation: 2-69                  [1, 500]                  --
# │    └─Activation: 2-70                  [1, 500]                  --
# │    └─Activation: 2-71                  [1, 500]                  --
# │    └─Activation: 2-72                  [1, 500]                  --
# │    └─Activation: 2-73                  [1, 500]                  --
# │    └─Activation: 2-74                  [1, 500]                  --
# │    └─Activation: 2-75                  [1, 500]                  --
# │    └─Activation: 2-76                  [1, 500]                  --
# │    └─Activation: 2-77                  [1, 500]                  --
# │    └─Activation: 2-78                  [1, 500]                  --
# │    └─Activation: 2-79                  [1, 500]                  --
# │    └─Activation: 2-80                  [1, 500]                  --
# │    └─Activation: 2-81                  [1, 500]                  --
# │    └─Activation: 2-82                  [1, 500]                  --
# │    └─Activation: 2-83                  [1, 500]                  --
# │    └─Activation: 2-84                  [1, 500]                  --
# │    └─Activation: 2-85                  [1, 500]                  --
# │    └─Activation: 2-86                  [1, 500]                  --
# │    └─Activation: 2-87                  [1, 500]                  --
# │    └─Activation: 2-88                  [1, 500]                  --
# │    └─Activation: 2-89                  [1, 500]                  --
# │    └─Activation: 2-90                  [1, 500]                  --
# │    └─Activation: 2-91                  [1, 500]                  --
# │    └─Activation: 2-92                  [1, 500]                  --
# │    └─Activation: 2-93                  [1, 500]                  --
# │    └─Activation: 2-94                  [1, 500]                  --
# │    └─Activation: 2-95                  [1, 500]                  --
# │    └─Activation: 2-96                  [1, 500]                  --
# │    └─Activation: 2-97                  [1, 500]                  --
# │    └─Activation: 2-98                  [1, 500]                  --
# │    └─Activation: 2-99                  [1, 500]                  --
# │    └─Activation: 2-100                 [1, 500]                  --
# │    └─Activation: 2-101                 [1, 500]                  --
# │    └─Activation: 2-102                 [1, 500]                  --
# │    └─Activation: 2-103                 [1, 500]                  --
# │    └─Activation: 2-104                 [1, 500]                  --
# │    └─Activation: 2-105                 [1, 500]                  --
# │    └─Activation: 2-106                 [1, 500]                  --
# │    └─Activation: 2-107                 [1, 500]                  --
# │    └─Activation: 2-108                 [1, 500]                  --
# │    └─Activation: 2-109                 [1, 500]                  --
# │    └─Activation: 2-110                 [1, 500]                  --
# │    └─Activation: 2-111                 [1, 500]                  --
# │    └─Activation: 2-112                 [1, 500]                  --
# │    └─Activation: 2-113                 [1, 500]                  --
# │    └─Activation: 2-114                 [1, 500]                  --
# │    └─Activation: 2-115                 [1, 500]                  --
# │    └─Activation: 2-116                 [1, 500]                  --
# │    └─Activation: 2-117                 [1, 500]                  --
# │    └─Activation: 2-118                 [1, 500]                  --
# │    └─Activation: 2-119                 [1, 500]                  --
# │    └─Activation: 2-120                 [1, 500]                  --
# │    └─Activation: 2-121                 [1, 500]                  --
# │    └─Activation: 2-122                 [1, 500]                  --
# │    └─Activation: 2-123                 [1, 500]                  --
# │    └─Activation: 2-124                 [1, 500]                  --
# │    └─Activation: 2-125                 [1, 500]                  --
# │    └─Activation: 2-126                 [1, 500]                  --
# │    └─Activation: 2-127                 [1, 500]                  --
# │    └─Activation: 2-128                 [1, 500]                  --
# │    └─Activation: 2-129                 [1, 500]                  --
# │    └─Activation: 2-130                 [1, 500]                  --
# │    └─Activation: 2-131                 [1, 500]                  --
# │    └─Activation: 2-132                 [1, 500]                  --
# │    └─Activation: 2-133                 [1, 500]                  --
# │    └─Activation: 2-134                 [1, 500]                  --
# │    └─Activation: 2-135                 [1, 500]                  --
# │    └─Activation: 2-136                 [1, 500]                  --
# │    └─Activation: 2-137                 [1, 500]                  --
# │    └─Activation: 2-138                 [1, 500]                  --
# │    └─Activation: 2-139                 [1, 500]                  --
# │    └─Activation: 2-140                 [1, 500]                  --
# │    └─Activation: 2-141                 [1, 500]                  --
# │    └─Activation: 2-142                 [1, 500]                  --
# │    └─Activation: 2-143                 [1, 500]                  --
# │    └─Activation: 2-144                 [1, 500]                  --
# │    └─Activation: 2-145                 [1, 500]                  --
# │    └─Activation: 2-146                 [1, 500]                  --
# │    └─Activation: 2-147                 [1, 500]                  --
# │    └─Activation: 2-148                 [1, 500]                  --
# │    └─Activation: 2-149                 [1, 500]                  --
# │    └─Activation: 2-150                 [1, 500]                  --
# │    └─Activation: 2-151                 [1, 500]                  --
# │    └─Activation: 2-152                 [1, 500]                  --
# │    └─Activation: 2-153                 [1, 500]                  --
# │    └─Activation: 2-154                 [1, 500]                  --
# │    └─Activation: 2-155                 [1, 500]                  --
# │    └─Activation: 2-156                 [1, 500]                  --
# │    └─Activation: 2-157                 [1, 500]                  --
# │    └─Activation: 2-158                 [1, 500]                  --
# │    └─Activation: 2-159                 [1, 500]                  --
# │    └─Activation: 2-160                 [1, 500]                  --
# │    └─Activation: 2-161                 [1, 500]                  --
# │    └─Activation: 2-162                 [1, 500]                  --
# │    └─Activation: 2-163                 [1, 500]                  --
# │    └─Activation: 2-164                 [1, 500]                  --
# │    └─Activation: 2-165                 [1, 500]                  --
# │    └─Activation: 2-166                 [1, 500]                  --
# │    └─Activation: 2-167                 [1, 500]                  --
# │    └─Activation: 2-168                 [1, 500]                  --
# │    └─Activation: 2-169                 [1, 500]                  --
# │    └─Activation: 2-170                 [1, 500]                  --
# │    └─Activation: 2-171                 [1, 500]                  --
# │    └─Activation: 2-172                 [1, 500]                  --
# │    └─Activation: 2-173                 [1, 500]                  --
# │    └─Activation: 2-174                 [1, 500]                  --
# │    └─Activation: 2-175                 [1, 500]                  --
# │    └─Activation: 2-176                 [1, 500]                  --
# │    └─Activation: 2-177                 [1, 500]                  --
# │    └─Activation: 2-178                 [1, 500]                  --
# │    └─Activation: 2-179                 [1, 500]                  --
# │    └─Activation: 2-180                 [1, 500]                  --
# │    └─Activation: 2-181                 [1, 500]                  --
# │    └─Activation: 2-182                 [1, 500]                  --
# │    └─Activation: 2-183                 [1, 500]                  --
# │    └─Activation: 2-184                 [1, 500]                  --
# │    └─Activation: 2-185                 [1, 500]                  --
# │    └─Activation: 2-186                 [1, 500]                  --
# │    └─Activation: 2-187                 [1, 500]                  --
# │    └─Activation: 2-188                 [1, 500]                  --
# │    └─Activation: 2-189                 [1, 500]                  --
# │    └─Activation: 2-190                 [1, 500]                  --
# │    └─Activation: 2-191                 [1, 500]                  --
# │    └─Activation: 2-192                 [1, 500]                  --
# │    └─Activation: 2-193                 [1, 500]                  --
# │    └─Activation: 2-194                 [1, 500]                  --
# │    └─Activation: 2-195                 [1, 500]                  --
# │    └─Activation: 2-196                 [1, 500]                  --
# │    └─Activation: 2-197                 [1, 500]                  --
# │    └─Activation: 2-198                 [1, 500]                  --
# │    └─Activation: 2-199                 [1, 500]                  --
# │    └─Activation: 2-200                 [1, 500]                  --
# ├─SVDReadout: 1-2                        [100, 1]                  --
# │    └─Linear: 2-201                     [100, 1]                  1,001
# ==========================================================================================
# Total params: 1,001
# Trainable params: 1,001
# Non-trainable params: 0
# Total mult-adds (M): 0.10
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.01
# ==========================================================================================

# %%
a = torch.arange(4.)
a
# Out:
# tensor([0., 1., 2., 3.])

# %% [markdown]
# #Using PCA Results to Reduce Training Time

# %%
import torch
import syft as sy
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import torch.nn.functional as F
import torch.nn
import torch.optim as optim
from auto_esn.esn.esn import DeepESN
#from auto_esn.esn.reservoir.util import NRMSELoss

class CarHackingDataset(Dataset):
    """
    Loading the Car-Hacking Dataset from
    https://ocslab.hksecurity.net/Datasets/car-hacking-dataset 

    Args:
        csv_file: A path to the dataset file which has the extension CSV.
        root_dir: The directory of the parent folder of the dataset.
        transform (callable, optional): Optional tansform to be applied on a sample.
    """
    def __init__(self, csv_file: str, root_dir: str, transform=None):
        self.car_hacking_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __getitem__(self,idx):
        '''Grabs relevant features from the dataset.'''
        if torch.is_tensor(idx):
            idx = idx.tolist()

        features = ['principal component 1', 'principal component 2']
        X_train = self.car_hacking_frame.loc[:, features].values
        X_train = torch.as_tensor(X_train)

        # It looks like it's a bad idea to encode features.
        # https://stackoverflow.com/questions/61217713/labelencoder-for-categorical-features

        return X_train[idx], self.car_hacking_frame['Flag'].iloc[idx]
            
    def __len__(self):
        return len(self.car_hacking_frame)

train_dataset = CarHackingDataset(csv_file='/content/car_hacking_data/balanced_pca_fuzzy_dataset.csv', 
                                  root_dir='/content/car_hacking_data')

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

hook = sy.TorchHook(torch)

car1 = sy.VirtualWorker(hook, id="car1")
car2 = sy.VirtualWorker(hook, id="car2")

args = {
    'batch_size' : 13084,
    'epochs' : 1
}

federated_train_loader = sy.FederatedDataLoader(train_dataset.federate((car1, car2)),
                                                batch_size=args['batch_size'], shuffle=True, drop_last=True)

# %%
from auto_esn.esn.esn import DeepESN
import time

def train(model, device, federated_train_loader, optimizer, epoch):
    model.train()

    for batch_idx, (data, target) in enumerate(federated_train_loader):
        model = model.send(data.location)

        data, target = data.reshape(args['batch_size'], 2, -1).to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)

        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        model.get()

        if batch_idx % 10 == 0:
            loss = loss.get()

            print(f'''Train Epoch: {epoch} [{(batch_idx * args['batch_size'])}/{(len(federated_train_loader) * args['batch_size'])}'''
                   + f'''({100. * batch_idx / len(federated_train_loader):.0f}%)]\tLoss: {loss.item():.6f}''')

model = DeepESN().to(device)

optimizer = optim.SGD(model.parameters(), lr=0.01)

t0 = time.time()
for epoch in range(1, args['batch_size'] + 1):
    train(model, device, federated_train_loader, optimizer, epoch)
t1 = time.time()
print(f'Training took {t1 - t0}s')
# Out:
# Training took 43.12057018280029s

# %% [markdown]
# #Changing the Loss Function and using NRMSE

# %%
from auto_esn.esn.esn import DeepESN
from auto_esn.esn.reservoir.util import NRMSELoss
import time

nrmse = NRMSELoss()

def train(model, device, federated_train_loader, optimizer, epoch):
    model.train()

    for batch_idx, (data, target) in enumerate(federated_train_loader):
        model = model.send(data.location)

        data, target = data.reshape(args['batch_size'], 2, -1).to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)

        loss = nrmse(output, target)
        loss.backward()
        optimizer.step()
        model.get()

        if batch_idx % 10 == 0:
            loss = loss.get()

            print(f'''Train Epoch: {epoch} [{(batch_idx * args['batch_size'])}/{(len(federated_train_loader) * args['batch_size'])}'''
                   + f'''({100. * batch_idx / len(federated_train_loader):.0f}%)]\tLoss: {loss.item():.6f}''')

model = DeepESN().to(device)

optimizer = optim.SGD(model.parameters(), lr=0.01)

t0 = time.time()
for epoch in range(1, args['batch_size'] + 1):
    train(model, device, federated_train_loader, optimizer, epoch)
t1 = time.time()
print(f'Training took {t1 - t0}s')
# Out:
# Training took 41.67633080482483s

# %% [markdown]
# #Checking the Data inside Virtual Workers

# %%
car1.msg_history
# Out:
# []

# %% [markdown]
# #Testing Concatanation for DeepESN

# %%
import torch

x = torch.randn(2, 3)
x
# Out:
# tensor([[-0.2088,  1.6677, -0.5772],
#         [ 0.1312,  1.1963, -1.2029]])

# %%
torch.cat((x, x, x), 0)
# Out:
# tensor([[-0.2088,  1.6677, -0.5772],
#         [ 0.1312,  1.1963, -1.2029],
#         [-0.2088,  1.6677, -0.5772],
#         [ 0.1312,  1.1963, -1.2029],
#         [-0.2088,  1.6677, -0.5772],
#         [ 0.1312,  1.1963, -1.2029]])

# %%
torch.cat((x, x, x), 1)
# Out:
# tensor([[-0.2088,  1.6677, -0.5772, -0.2088,  1.6677, -0.5772, -0.2088,  1.6677,
#          -0.5772],
#         [ 0.1312,  1.1963, -1.2029,  0.1312,  1.1963, -1.2029,  0.1312,  1.1963,
#          -1.2029]])

# %% [markdown]
# #Tensor Manipulation

# %%
import torch

x = torch.tensor([0.5, 0.2, 0.3, 0.4])
x = x.reshape(4,1)

y = torch.tensor([1.])
y = y.repeat(4, 1)
print(y)


m = nn.Sigmoid()
loss = nn.BCELoss()
output = loss(m(x), y)
print(output)
# Out:
# tensor([[1.],
#         [1.],
#         [1.],
#         [1.]])
# tensor(0.5349)

# %% [markdown]
# #Loss Function Testing

# %%
import torch.nn as nn

m = nn.Sigmoid()
loss = nn.BCELoss()
input = torch.randn(3, requires_grad=True)
print(input)
target = torch.empty(3).random_(3)
print(target)
output = loss(m(input), target)
print(output) #tensor(0.4198, grad_fn=<BinaryCrossEntropyBackward>)
# Out:
# tensor([ 0.7086, -1.0160, -0.2988], requires_grad=True)
# tensor([0., 1., 1.])
# tensor(1.0959, grad_fn=<BinaryCrossEntropyBackward>)

# %%
target_1 = torch.tensor([0.0])
correct = 0


correct += pred.eq(target.view_as(pred)).sum().item()

# %% [markdown]
# #Using EchoTorch for ESN

# %%
# !pip install EchoTorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting EchoTorch
#   Downloading EchoTorch-0.1.1.tar.gz (22 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from EchoTorch) (1.12.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from EchoTorch) (1.21.6)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from EchoTorch) (0.13.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->EchoTorch) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->EchoTorch) (2.23.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->EchoTorch) (7.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->EchoTorch) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->EchoTorch) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->EchoTorch) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->EchoTorch) (3.0.4)
# Building wheels for collected packages: EchoTorch
#   Building wheel for EchoTorch (setup.py) ... done
#   Created wheel for EchoTorch: filename=EchoTorch-0.1.1-py3-none-any.whl size=55562 sha256=452a0fd0929278bca13e4ab0c13c8521612f7b482ec25473e0f01ef40974192f
#   Stored in directory: /root/.cache/pip/wheels/69/fc/7c/c7d0886395ed9b689a4c5442ea99d3c968768667163297e276
# Successfully built EchoTorch
# Installing collected packages: EchoTorch
# Successfully installed EchoTorch-0.1.1

# %%
esn = etnn.LiESN()

# %% [markdown]
# # Using PyESN

# %%
from pyESN import ESN
from torchinfo import summary

esn = ESN(n_inputs = 4,
          n_outputs = 1,
          n_reservoir = 10,
          spectral_radius = 1.5,
          random_state=42)

summary(esn, input_size=(10, 1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-75ad3d5608e9> in <module>
#       8           random_state=42)
#       9
# ---> 10 summary(esn, input_size=(10, 1))
#
# /usr/local/lib/python3.7/dist-packages/torchinfo/torchinfo.py in summary(model, input_size, input_data, batch_dim, cache_forward_pass, col_names, col_width, depth, device, dtypes, mode, row_settings, verbose, **kwargs)
#     216     )
#     217     summary_list = forward_pass(
# --> 218         model, x, batch_dim, cache_forward_pass, device, model_mode, **kwargs
#     219     )
#     220     formatting = FormattingOptions(depth, verbose, columns, col_width, rows)
#
# /usr/local/lib/python3.7/dist-packages/torchinfo/torchinfo.py in forward_pass(model, x, batch_dim, cache_forward_pass, device, mode, **kwargs)
#     266         return _cached_forward_pass[model_name]
#     267
# --> 268     summary_list, _, hooks = apply_hooks(model_name, model, x, batch_dim)
#     269     if x is None:
#     270         set_children_layers(summary_list)
#
# /usr/local/lib/python3.7/dist-packages/torchinfo/torchinfo.py in apply_hooks(model_name, module, input_data, batch_dim)
#     586         # ModuleLists or Sequentials.
#     587         global_layer_info[module_id] = LayerInfo(
# --> 588             var_name, module, curr_depth, parent_info
#     589         )
#     590         pre_hook = construct_pre_hook(
#
# /usr/local/lib/python3.7/dist-packages/torchinfo/layer_info.py in __init__(self, var_name, module, depth, parent_info)
#      49         self.parent_info = parent_info
#      50         self.var_name = var_name
# ---> 51         self.is_leaf_layer = not any(self.module.children())
#      52         self.contains_lazy_param = False
#      53
#
# AttributeError: 'ESN' object has no attribute 'children'

# %%
import torch
import syft as sy
import pandas as pd
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.nn
import torch.optim as optim

class CarHackingDataset(Dataset):
    """
    Loading the Car-Hacking Dataset from
    https://ocslab.hksecurity.net/Datasets/car-hacking-dataset 

    Args:
        csv_file: A path to the dataset file which has the extension CSV.
        root_dir: The directory of the parent folder of the dataset.
        transform (callable, optional): Optional tansform to be applied on a sample.
    """
    def __init__(self, csv_file: str, root_dir: str, transform=None):
        self.car_hacking_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __getitem__(self,idx):
        '''Grabs relevant features from the dataset.'''
        if torch.is_tensor(idx):
            idx = idx.tolist()

        features = ['Timestamp', 'DLC', 'CAN_ID', 'Data']
        X_train = self.car_hacking_frame.loc[:, features].values
        X_train = torch.as_tensor(X_train)

        # It looks like it's a bad idea to encode features.
        # https://stackoverflow.com/questions/61217713/labelencoder-for-categorical-features

        y = self.car_hacking_frame['Flag'].iloc[idx]
        y = torch.as_tensor(y)

        return X_train[idx], y
            
    def __len__(self):
        return len(self.car_hacking_frame)

class ValidationDataset(Dataset):
    def __init__(self, csv_file: str, root_dir: str, transform=None):
        self.validation_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __getitem__(self, idx):
        '''Grabs relevant features from the dataset.'''
        if torch.is_tensor(idx):
            idx = idx.tolist()

        features = ['Timestamp', 'DLC', 'CAN_ID', 'Data']
        X_train = self.validation_frame.loc[:, features].values
        X_train = torch.as_tensor(X_train, dtype=torch.float32)
        y = self.validation_frame['Flag'].iloc[idx]
        y = torch.as_tensor(y, dtype=torch.float32)

        return X_train[idx], y

    def __len__(self):
        return len(self.validation_frame)

train_dataset = CarHackingDataset(csv_file='/content/car_hacking_data/split_fuzzy_dataset_1_training.csv', 
                                  root_dir='/content/car_hacking_data')

test_loader = ValidationDataset(csv_file='/content/car_hacking_data/split_fuzzy_dataset_1_testing.csv', 
                                 root_dir='/content/car_hacking_data')

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

hook = sy.TorchHook(torch)

car1 = sy.VirtualWorker(hook, id="car1")
car2 = sy.VirtualWorker(hook, id="car2")

args = {
    'batch_size' : train_dataset.__len__(),
    'epochs' : 15
}

federated_train_loader = sy.FederatedDataLoader(train_dataset.federate((car1, car2)),
                                                batch_size=args['batch_size'], shuffle=True, drop_last=True)

# %%
import time
from sklearn.metrics import balanced_accuracy_score
import torch.nn as nn

def train(model, device, federated_train_loader, optimizer, epoch):
    model.train()

    for batch_idx, (data, target) in enumerate(federated_train_loader):
        model = model.send(data.location)

        data, target = data.reshape(args['batch_size'], 4, -1).to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)

        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        model.get()

        print(batch_idx)

        if batch_idx % 10 == 0:
            loss = loss.get()

            print(f'''Train Epoch: {epoch} [{(batch_idx * args['batch_size'])}/{(len(federated_train_loader) * args['batch_size'])}'''
                   + f'''({100. * batch_idx / len(federated_train_loader):.0f}%)]\tLoss: {loss.item():.6f}''')

def test(model, device, test_loader):
    model.eval()

    test_loss = 0
    correct = 0
    m = nn.Sigmoid()
    loss = nn.BCELoss()

    with torch.no_grad():
        for data, target in test_loader:
            #data, target = data.reshape(-1, 4, 1).to(device), target.to(device)
            data = data.reshape(-1, 1, 1).to(device)
            target = target.to(device)
            output = model(data)

            y = target.repeat(4, 1)
            test_loss = loss(m(data), y)

            #test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            # print(y.view_as(pred))
            y = y.reshape(4, 1, -1)
            #correct += pred.eq(y.view_as(pred)).sum().item()

    #test_loss /= test_loader.__len__
    print(f"Test Loss: {test_loss}, Correct: {correct}, Accuracy: {balanced_accuracy_score(y, pred)}")

    '''print("\n Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n".format(
          test_loss, correct, test_loader.__len__,
          100. * correct/test_loader.__len__))'''

model = ESN(n_inputs = 4,
            n_outputs = 1,
            n_reservoir = 10,
            spectral_radius = 1.5,
            random_state=42).to(device)

optimizer = optim.SGD(model.parameters(), lr=0.01)

t0 = time.time()
for epoch in range(1, args['batch_size'] + 1):
    train(model, device, federated_train_loader, optimizer, epoch)
    test(model, device, test_loader)
t1 = time.time()
print(f'Training took {t1 - t0}s')
